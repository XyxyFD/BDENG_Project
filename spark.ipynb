# %% [markdown]
# # Spark Exercise
#
# Apache Spark is an excellent tool for data engineering projects due to its robust ability to process large-scale data efficiently through distributed computing. Spark's in-memory processing capabilities significantly enhance the speed of data operations, making it ideal for handling big data workloads. It supports various data sources and formats, offering versatility in data ingestion and transformation. Additionally, Spark's rich API supports multiple programming languages such as Python, Java, and Scala, catering to diverse developer preferences. Its ecosystem, which includes libraries for SQL, machine learning, and graph processing, provides a comprehensive suite for building complex data pipelines and analytics, making it a powerful and flexible choice for data engineering tasks.

# %% [markdown]
# Use Python, ```pyspark``` and ```pandas``` to explore Apache Spark RDD and DataFrame:

# %% [markdown]
# # Spark RDD
#
# Spark RDD (Resilient Distributed Dataset) is a fundamental data structure in Apache Spark that enables fault-tolerant, distributed processing of large datasets across multiple nodes in a cluster. Spark RDDs provide a higher-level abstraction for performing distributed data processing tasks, including both map (transformations) and reduce (aggregations) operations.

# %% [markdown]
# ## Import Necessary Libraries

# %%
from pyspark import SparkConf, SparkContext
from pyspark.sql import SparkSession
import pandas as pd

# %% [markdown]
# ## Spark Context and Session
# Initialize Spark Context and Spark Session

# %%
spark = (
    SparkSession
    .builder
    .appName("LoadClosingOddsRDD")
    .config("spark.master", "local[*]")
    .getOrCreate()
)

sc = spark.sparkContext
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/05/26 16:10:08 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 25/05/26 16:10:08 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 25/05/26 16:10:08 WARN Utils: Service 'SparkUI' could not bind on port 4041. Attempting port 4042.
# 25/05/26 16:10:08 WARN Utils: Service 'SparkUI' could not bind on port 4042. Attempting port 4043.
# 25/05/26 16:10:08 WARN Utils: Service 'SparkUI' could not bind on port 4043. Attempting port 4044.

# %% [markdown]
# ## Load Data into RDD

# %%
csv_path = "closing_odds.csv"
df = pd.read_csv(
    csv_path,
    compression="gzip",      
    encoding="utf-8",        
)

data_tuples = list(df.itertuples(index=False, name=None))

rdd = sc.parallelize(data_tuples)

# %% [markdown]
# ## Map Operation
#
# Split data into individual parts and create key-value pairs

# %%
rdd_kv = rdd.map(lambda tup: (tup[0], tup[1:]))
print("key-value pairs:")
for kv in rdd_kv.take(5):
    print(kv)
# Out:
# key-value pairs:
# 25/05/26 16:13:30 WARN TaskSetManager: Stage 0 contains a task of very large size (13042 KiB). The maximum recommended task size is 1000 KiB.
# [Stage 0:>                                                          (0 + 1) / 1]
# (170088, ('England: Premier League', '2005-01-01', 'Liverpool', 0, 'Chelsea', 1, 2.9944, 3.1944, 2.2256, 3.2, 3.25, 2.29, 'Paddy Power', 'Sportingbet', 'Expekt', 9, 9, 9))
# (170089, ('England: Premier League', '2005-01-01', 'Fulham', 3, 'Crystal Palace', 1, 1.9456, 3.2333, 3.6722, 2.04, 3.3, 4.15, 'Pinnacle Sports', 'bet-at-home', 'Expekt', 9, 9, 9))
# (170090, ('England: Premier League', '2005-01-01', 'Aston Villa', 1, 'Blackburn', 0, 1.8522, 3.2611, 4.0144, 2.0, 3.4, 4.5, 'Pinnacle Sports', 'Paddy Power', 'Sportingbet', 9, 9, 9))
# (170091, ('England: Premier League', '2005-01-01', 'Bolton', 1, 'West Brom', 1, 1.6122, 3.4133, 5.4722, 1.67, 3.57, 6.27, 'Coral', 'Pinnacle Sports', 'Pinnacle Sports', 9, 9, 9))
# (170092, ('England: Premier League', '2005-01-01', 'Charlton', 1, 'Arsenal', 3, 5.9878, 3.4778, 1.5567, 7.0, 3.6, 1.62, 'Expekt', 'Paddy Power', 'bet365', 9, 9, 9))

# %% [markdown]
# ## Reduce Operation
#
# Reduce your key-value pairs

# %%
matches_per_league_rdd = (
    rdd_kv
    .map(lambda parts: (parts[1], 1))            
    .reduceByKey(lambda a, b: a + b)            
)

for league, count in matches_per_league_rdd.take(10):
    print(f"{league}: {count} games")
# Out:
# 25/05/26 16:13:41 WARN TaskSetManager: Stage 1 contains a task of very large size (13042 KiB). The maximum recommended task size is 1000 KiB.
# [Stage 1:============================================>              (3 + 1) / 4]
# ('England: Premier League', '2005-01-01', 'Aston Villa', 1, 'Blackburn', 0, 1.8522, 3.2611, 4.0144, 2.0, 3.4, 4.5, 'Pinnacle Sports', 'Paddy Power', 'Sportingbet', 9, 9, 9): 1 games
# ('England: Championship', '2005-01-01', 'Derby', 0, 'Cardiff', 1, 1.6875, 3.3625, 4.5188, 1.73, 3.5, 5.5, 'bet365', 'bet365', 'Coral', 8, 8, 8): 1 games
# ('England: Championship', '2005-01-01', 'QPR', 0, 'Brighton', 0, 1.8388, 3.2888, 3.7788, 1.9, 3.66, 4.03, 'Expekt', 'Pinnacle Sports', 'Pinnacle Sports', 8, 8, 8): 1 games
# ('England: Championship', '2005-01-01', 'Sheffield Utd', 0, 'Wigan', 2, 2.25, 3.2188, 2.7888, 2.4, 3.25, 3.0, 'Expekt', 'bet365', 'Ladbrokes', 8, 8, 8): 1 games
# ('England: Championship', '2005-01-01', 'Wolves', 1, 'Plymouth', 1, 1.8713, 3.2625, 3.675, 2.0, 3.4, 4.0, 'Pinnacle Sports', 'Pinnacle Sports', 'Sportingbet', 8, 8, 8): 1 games
# ('England: League One', '2005-01-01', 'Bristol City', 2, 'Peterborough', 0, 1.5378, 3.48, 5.6656, 1.57, 3.6, 6.54, 'bet365', 'bet365', 'Pinnacle Sports', 9, 9, 9): 1 games
# ('England: League One', '2005-01-01', 'Oldham', 2, 'Tranmere', 2, 2.5444, 3.2044, 2.45, 2.65, 3.34, 2.6, 'Expekt', 'Pinnacle Sports', 'Sportingbet', 9, 9, 9): 1 games
# ('England: League Two', '2005-01-01', 'Cambridge Utd', 0, 'Boston', 1, 2.4856, 3.1744, 2.5211, 2.7, 3.25, 2.65, 'Pinnacle Sports', 'Ladbrokes', 'Expekt', 9, 9, 9): 1 games
# ('England: League Two', '2005-01-01', 'Leyton Orient', 2, 'Kidderminster', 1, 1.6178, 3.4567, 4.7778, 1.74, 3.51, 5.15, 'Pinnacle Sports', 'Pinnacle Sports', 'Expekt', 9, 9, 9): 1 games
# ('England: League Two', '2005-01-01', 'Macclesfield', 1, 'Chester', 2, 1.7822, 3.3, 4.0, 1.85, 3.5, 4.34, 'Expekt', 'bet365', 'Pinnacle Sports', 9, 9, 9): 1 games

# %% [markdown]
# ## Collect Results
#
# Because of lazy evaluation, the map-reduce operation is performed only now. Show what you calculated.

# %%
matches_per_league_rdd.collect()
# Out:
# [(('England: Premier League',
#    '2005-01-01',
#    'Aston Villa',
#    1,
#    'Blackburn',
#    0,
#    1.8522,
#    3.2611,
#    4.0144,
#    2.0,
#    3.4,
#    4.5,
#    'Pinnacle Sports',
#    'Paddy Power',
#    'Sportingbet',
#    9,
#    9,
#    9),
#   1),
#  (('England: Championship',
#    '2005-01-01',
#    'Derby',
#    0,
#    'Cardiff',
#    1,
#    1.6875,
#    3.3625,
#    4.5188,
#    1.73,
#    3.5,
#    5.5,
#    'bet365',
#    'bet365',
#    'Coral',
#    8,
#    8,
#    8),
#   1),
#  (('England: Championship',
#    '2005-01-01',
#    'QPR',
#    0,
#    'Brighton',
#    0,
#    1.8388,
#    3.2888,
#    3.7788,
#    1.9,
#    3.66,
#    4.03,
#    'Expekt',
#    'Pinnacle Sports',
#    'Pinnacle Sports',
#    8,
#    8,
#    8),
#   1),
#  (('England: Championship',
#    '2005-01-01',
#    'Sheffield Utd',
#    0,
#    'Wigan',
#    2,
#    2.25,
#    3.2188,
#    2.7888,
#    2.4,
#    3.25,
#    3.0,
#    'Expekt',
#    'bet365',
#    'Ladbrokes',
#    8,
#    8,
#    8),
#   1),
#  (('England: Championship',
#    '2005-01-01',
#    'Wolves',
#    1,
#    'Plymouth',
#    1,
#    1.8713,
#    3.2625,
#    3.675,
#    2.0,
#    3.4,
#    4.0,
#    'Pinnacle Sports',
#    'Pinnacle Sports',
#    'Sportingbet',
#    8,
#    8,
#    8),
#   1),
#  (('England: League One',
#    '2005-01-01',
#    'Bristol City',
#    2,
#    'Peterborough',
#    0,
#    1.5378,
#    3.48,
#    5.6656,
#    1.57,
#    3.6,
#    6.54,
#    'bet365',
#    'bet365',
#    'Pinnacle Sports',
#    9,
#    9,
#    9),
#   1),
#  (('England: League One',
#    '2005-01-01',
#    'Oldham',
#    2,
#    'Tranmere',
#    2,
#    2.5444,
#    3.2044,
#    2.45,
#    2.65,
#    3.34,
#    2.6,
#    'Expekt',
#    'Pinnacle Sports',
#    'Sportingbet',
#    9,
#    9,
#    9),
#   1),
#  (('England: League Two',
#    '2005-01-01',
#    'Cambridge Utd',
#    0,
#    'Boston',
#    1,
#    2.4856,
#    3.1744,
#    2.5211,
#    2.7,
#    3.25,
#    2.65,
#    'Pinnacle Sports',
#    'Ladbrokes',
#    'Expekt',
#    9,
#    9,
#    9),
#   1),
#  (('England: League Two',
#    '2005-01-01',
#    'Leyton Orient',
#    2,
#    'Kidderminster',
#    1,
#    1.6178,
#    3.4567,
#    4.7778,
#    1.74,
#    3.51,
#    5.15,
#    'Pinnacle Sports',
#    'Pinnacle Sports',
#    'Expekt',
#    9,
#    9,
#    9),
#   1),
#  (('England: League Two',
#    '2005-01-01',
#    'Macclesfield',
#    1,
#    'Chester',
#    2,
#    1.7822,
#    3.3,
#    4.0,
#    1.85,
#    3.5,
#    4.34,
#    'Expekt',
#    'bet365',
#    'Pinnacle Sports',
#    9,
#    9,
#    9),
#   1),
#  (('England: League Two',
#    '2005-01-01',
#    'Shrewsbury',
#    2,
#    'Bristol Rovers',
#    0,
#    2.3544,
#    3.2122,
#    2.6433,
#    2.44,
#    3.36,
#    2.75,
#    'Pinnacle Sports',
#    'Pinnacle Sports',
#    'Sportingbet',
#    9,
#    9,
#    9),
#   1),
#  (('England: League Two',
#    '2005-01-01',
#    'Southend',
#    3,
#    'Rushden',
#    0,
#    1.65,
#    3.41,
#    4.5767,
#    1.67,
#    3.54,
#    5.0,
#    'bet365',
#    'Pinnacle Sports',
#    'Paddy Power',
#    9,
#    9,
#    9),
#   1),
#  (('England: Nationwide Conference',
#    '2005-01-01',
#    'Forest Green',
#    0,
#    'Aldershot',
#    0,
#    2.4925,
#    3.2375,
#    2.4725,
#    2.6,
#    3.4,
#    2.6,
#    'Sportingbet',
#    'William Hill',
#    'Ladbrokes',
#    8,
#    8,
#    8),
#   1),
#  (('England: Nationwide Conference',
#    '2005-01-01',
#    'Tamworth',
#    0,
#    'Burton',
#    2,
#    1.86,
#    3.29,
#    3.6275,
#    2.0,
#    3.4,
#    3.92,
#    'bet365',
#    'Sportingbet',
#    'Pinnacle Sports',
#    8,
#    8,
#    8),
#   1),
#  (('England: Nationwide Conference',
#    '2005-01-01',
#    'Farnborough',
#    0,
#    'Woking',
#    0,
#    2.5938,
#    3.2725,
#    2.36,
#    2.76,
#    3.4,
#    2.4,
#    'Pinnacle Sports',
#    'bet365',
#    'Sportingbet',
#    8,
#    8,
#    8),
#   1),
#  (('Northern Ireland: IFA Premiership',
#    '2005-01-01',
#    'Coleraine',
#    3,
#    'Omagh Town',
#    4,
#    1.29,
#    4.5,
#    8.0,
#    1.29,
#    4.5,
#    8.0,
#    'Paddy Power',
#    'Paddy Power',
#    'Paddy Power',
#    1,
#    1,
#    1),
#   1),
#  (('Northern Ireland: IFA Premiership',
#    '2005-01-01',
#    'Dungannon',
#    7,
#    'Ards',
#    0,
#    2.25,
#    3.2,
#    2.75,
#    2.25,
#    3.2,
#    2.75,
#    'Paddy Power',
#    'Paddy Power',
#    'Paddy Power',
#    1,
#    1,
#    1),
#   1),
#  (('Northern Ireland: IFA Premiership',
#    '2005-01-01',
#    'Loughgall',
#    0,
#    'Linfield',
#    4,
#    5.5,
#    3.6,
#    1.5,
#    5.5,
#    3.6,
#    1.5,
#    'Paddy Power',
#    'Paddy Power',
#    'Paddy Power',
#    1,
#    1,
#    1),
#   1),
#  (('Scotland: Premier League',
#    '2005-01-01',
#    'Dundee Utd',
#    1,
#    'Rangers',
#    1,
#    9.8822,
#    5.2111,
#    1.2122,
#    10.5,
#    5.7,
#    1.25,
#    'Expekt',
#    'Expekt',
#    'Ladbrokes',
#    9,
#    9,
#    9),
#   1),
#  (('Scotland: Premier League',
#    '2005-01-01',
#    'Dunfermline',
#    3,
#    'Dundee FC',
#    1,
#    2.0333,
#    3.2389,
#    3.1944,
#    2.1,
#    3.3,
#    3.45,
#    'Coral',
#    'Pinnacle Sports',
#    'bet-at-home',
#    9,
#    9,
#    9),
#   1),
#  (('Scotland: Division 1',
#    '2005-01-01',
#    'Clyde',
#    1,
#    'Airdrieonians',
#    0,
#    1.89,
#    3.5033,
#    3.2678,
#    1.97,
#    3.63,
#    3.4,
#    'Pinnacle Sports',
#    'Pinnacle Sports',
#    'Coral',
#    9,
#    9,
#    9),
#   1),
#  (('England: Championship',
#    '2005-01-03',
#    'Millwall',
#    1,
#    'Rotherham',
#    2,
#    1.4425,
#    3.7538,
#    6.4763,
#    1.49,
#    4.0,
#    7.0,
#    'Pinnacle Sports',
#    'Sportingbet',
#    'Expekt',
#    8,
#    8,
#    8),
#   1),
#  (('England: Championship',
#    '2005-01-03',
#    'West Ham',
#    0,
#    'Sheffield Utd',
#    2,
#    1.9375,
#    3.2563,
#    3.4625,
#    2.0,
#    3.3,
#    3.85,
#    'Coral',
#    'Expekt',
#    'Expekt',
#    8,
#    8,
#    8),
#   1),
#  (('England: League One',
#    '2005-01-03',
#    'Blackpool',
#    0,
#    'Port Vale',
#    2,
#    2.12,
#    3.23,
#    3.0178,
#    2.25,
#    3.4,
#    3.39,
#    'Ladbrokes',
#    'Ladbrokes',
#    'Pinnacle Sports',
#    9,
#    9,
#    9),
#   1),
#  (('England: League One',
#    '2005-01-03',
#    'Colchester',
#    0,
#    'Oldham',
#    0,
#    2.1067,
#    3.2356,
#    3.0211,
#    2.2,
#    3.42,
#    3.2,
#    'bet365',
#    'Pinnacle Sports',
#    'Ladbrokes',
#    9,
#    9,
#    9),
#   1),
#  (('England: League Two',
#    '2005-01-03',
#    'Boston',
#    2,
#    'Leyton Orient',
#    2,
#    1.9833,
#    3.2478,
#    3.3111,
#    2.1,
#    3.43,
#    3.6,
#    'bet365',
#    'Pinnacle Sports',
#    'Pinnacle Sports',
#    9,
#    9,
#    9),
#   1),
#  (('England: League Two',
#    '2005-01-03',
#    'Bury',
#    0,
#    'Oxford Utd',
#    0,
#    2.0067,
#    3.2333,
#    3.2467,
#    2.1,
#    3.3,
#    3.5,
#    'William Hill',
#    'Pinnacle Sports',
#    'Ladbrokes',
#    9,
#    9,
#    9),
#   1),
#  (('England: League Two',
#    '2005-01-03',
#    'Darlington',
#    3,
#    'Macclesfield',
#    1,
#    2.0178,
#    3.2567,
#    3.1956,
#    2.1,
#    3.51,
#    3.41,
#    'bet-at-home',
#    'Pinnacle Sports',
#    'Pinnacle Sports',
#    9,
#    9,
#    9),
#   1),
#  (('England: League Two',
#    '2005-01-03',
#    'Kidderminster',
#    1,
#    'Southend',
#    3,
#    2.87,
#    3.2222,
#    2.1889,
#    3.1,
#    3.25,
#    2.25,
#    'Pinnacle Sports',
#    'bet365',
#    'Coral',
#    9,
#    9,
#    9),
#   1),
#  (('Northern Ireland: IFA Premiership',
#    '2005-01-03',
#    'Linfield',
#    2,
#    'Dungannon',
#    1,
#    1.22,
#    5.0,
#    9.5,
#    1.22,
#    5.0,
#    9.5,
#    'Paddy Power',
#    'Paddy Power',
#    'Paddy Power',
#    1,
#    1,
#    1),
#   1),
#  (('Northern Ireland: IFA Premiership',
#    '2005-01-03',
#    'Lisburn',
#    3,
#    'Cliftonville',
#    1,
#    2.1,
#    3.2,
#    3.0,
#    2.1,
#    3.2,
#    3.0,
#    'Paddy Power',
#    'Paddy Power',
#    'Paddy Power',
#    1,
#    1,
#    1),
#   1),
#  (('Northern Ireland: IFA Premiership',
#    '2005-01-03',
#    'Portadown',
#    4,
#    'Glentoran',
#    3,
#    2.4,
#    3.25,
#    2.5,
#    2.4,
#    3.25,
#    2.5,
#    'Paddy Power',
#    'Paddy Power',
#    'Paddy Power',
#    1,
#    1,
#    1),
#   1),
#  (('Scotland: Premier League',
#    '2005-01-03',
#    'Inverness',
#    0,
#    'Kilmarnock',
#    2,
#    2.2144,
#    3.2122,
#    2.8411,
#    2.29,
#    3.25,
#    3.04,
#    'bet365',
#    'Expekt',
#    'Pinnacle Sports',
#    9,
#    9,
#    9),
#   1),
#  (('Scotland: Division 2',
#    '2005-01-03',
#    'Brechin',
#    2,
#    'Alloa',
#    3,
#    1.4714,
#    3.9329,
#    5.3129,
#    1.5,
#    4.33,
#    5.69,
#    'bet365',
#    'Ladbrokes',
#    'Pinnacle Sports',
#    7,
#    7,
#    7),
#   1),
#  (('Scotland: Division 3',
#    '2005-01-03',
#    'Albion Rovers',
#    0,
#    'Peterhead',
#    4,
#    8.6414,
#    5.2143,
#    1.23,
#    9.99,
#    5.5,
#    1.25,
#    'Ladbrokes',
#    'Coral',
#    'Paddy Power',
#    7,
#    7,
#    7),
#   1),
#  (('Wales: Premier',
#    '2005-01-03',
#    'Caersws FC',
#    2,
#    'Newtown',
#    0,
#    1.73,
#    3.4,
#    4.0,
#    1.73,
#    3.4,
#    4.0,
#    'bet365',
#    'bet365',
#    'bet365',
#    1,
#    1,
#    1),
#   1),
#  (('England: Premier League',
#    '2005-01-04',
#    'Birmingham',
#    1,
#    'Bolton',
#    2,
#    1.8233,
#    3.2722,
#    4.1144,
#    1.99,
#    3.4,
#    4.5,
#    'Pinnacle Sports',
#    'Coral',
#    'bet365',
#    9,
#    9,
#    9),
#   1),
#  (('England: Premier League',
#    '2005-01-04',
#    'Chelsea',
#    2,
#    'Middlesbrough',
#    0,
#    1.3367,
#    4.2989,
#    8.7211,
#    1.36,
#    5.0,
#    9.99,
#    'bet365',
#    'Expekt',
#    'Expekt',
#    9,
#    9,
#    9),
#   1),
#  (('England: Premier League',
#    '2005-01-04',
#    'Everton',
#    2,
#    'Portsmouth',
#    1,
#    1.7356,
#    3.2889,
#    4.6056,
#    1.83,
#    3.4,
#    5.0,
#    'Pinnacle Sports',
#    'Sportingbet',
#    'bet365',
#    9,
#    9,
#    9),
#   1),
#  (('Greece: Greek Cup',
#    '2005-01-05',
#    'Kalamaria',
#    1,
#    'Panserraikos',
#    1,
#    1.55,
#    3.3,
#    4.9,
#    1.55,
#    3.3,
#    4.9,
#    'bet-at-home',
#    'bet-at-home',
#    'bet-at-home',
#    1,
#    1,
#    1),
#   1),
#  (('Greece: Greek Cup',
#    '2005-01-05',
#    'OFI Crete',
#    5,
#    'Thyella Patras',
#    1,
#    1.05,
#    8.25,
#    9.99,
#    1.05,
#    9.0,
#    9.99,
#    'bet-at-home',
#    'Expekt',
#    'bet-at-home',
#    2,
#    2,
#    2),
#   1),
#  (('Greece: Greek Cup',
#    '2005-01-05',
#    'Atromitos',
#    0,
#    'Aris',
#    5,
#    8.245,
#    4.945,
#    1.25,
#    9.99,
#    5.09,
#    1.3,
#    'bet-at-home',
#    'Expekt',
#    'Expekt',
#    2,
#    2,
#    2),
#   1),
#  (('Italy: Serie A',
#    '2005-01-06',
#    'AC Milan',
#    5,
#    'Lecce',
#    2,
#    1.27,
#    4.5138,
#    9.3713,
#    1.3,
#    5.0,
#    9.99,
#    'William Hill',
#    'Pinnacle Sports',
#    'bet-at-home',
#    8,
#    8,
#    8),
#   1),
#  (('Italy: Serie A',
#    '2005-01-06',
#    'Lazio',
#    3,
#    'AS Roma',
#    1,
#    3.685,
#    3.01,
#    2.02,
#    4.0,
#    3.1,
#    2.2,
#    'bet365',
#    'bet365',
#    'Ladbrokes',
#    8,
#    8,
#    8),
#   1),
#  (('France: Coupe de France',
#    '2005-01-07',
#    'Sedan',
#    3,
#    'Strasbourg',
#    1,
#    2.3725,
#    2.8088,
#    2.9225,
#    2.41,
#    2.9,
#    3.46,
#    'Pinnacle Sports',
#    'Sportingbet',
#    'Pinnacle Sports',
#    8,
#    8,
#    8),
#   1),
#  (('France: Coupe de France',
#    '2005-01-07',
#    'Chateauroux',
#    2,
#    'Grenoble',
#    2,
#    1.8213,
#    2.9338,
#    4.38,
#    1.91,
#    3.2,
#    5.13,
#    'Ladbrokes',
#    'bet365',
#    'Pinnacle Sports',
#    8,
#    8,
#    8),
#   1),
#  (('England: League One',
#    '2005-01-08',
#    'Doncaster',
#    2,
#    'Port Vale',
#    0,
#    1.8856,
#    3.2478,
#    3.6144,
#    1.91,
#    3.33,
#    3.85,
#    'Coral',
#    'Pinnacle Sports',
#    'Expekt',
#    9,
#    9,
#    9),
#   1),
#  (('England: League Two',
#    '2005-01-08',
#    'Bristol Rovers',
#    1,
#    'Cambridge Utd',
#    1,
#    1.5656,
#    3.4867,
#    5.3044,
#    1.6,
#    3.6,
#    6.04,
#    'Expekt',
#    'bet365',
#    'Pinnacle Sports',
#    9,
#    9,
#    9),
#   1),
#  (('England: League Two',
#    '2005-01-08',
#    'Bury',
#    0,
#    'Leyton Orient',
#    0,
#    2.2833,
#    3.1922,
#    2.7522,
#    2.38,
#    3.25,
#    3.02,
#    'Coral',
#    'Coral',
#    'Pinnacle Sports',
#    9,
#    9,
#    9),
#   1),
#  (('England: Nationwide Conference',
#    '2005-01-08',
#    'Accrington',
#    2,
#    'Farnborough',
#    1,
#    1.6438,
#    3.405,
#    4.7125,
#    1.7,
#    3.45,
#    5.25,
#    'William Hill',
#    'Pinnacle Sports',
#    'Pinnacle Sports',
#    8,
#    8,
#    8),
#   1),
#  (('England: Nationwide Conference',
#    '2005-01-08',
#    'Aldershot',
#    4,
#    'Tamworth',
#    3,
#    1.8463,
#    3.3613,
#    3.5925,
#    1.9,
#    3.4,
#    3.75,
#    'bet365',
#    'Coral',
#    'Ladbrokes',
#    8,
#    8,
#    8),
#   1),
#  (('England: Nationwide Conference',
#    '2005-01-08',
#    'Burton',
#    3,
#    'Hereford',
#    0,
#    3.2063,
#    3.2813,
#    2.0,
#    3.4,
#    3.5,
#    2.1,
#    'Sportingbet',
#    'Pinnacle Sports',
#    'Expekt',
#    8,
#    8,
#    8),
#   1),
#  (('England: Nationwide Conference',
#    '2005-01-08',
#    'Crawley Town',
#    1,
#    'Carlisle',
#    0,
#    2.6688,
#    3.2438,
#    2.3225,
#    2.75,
#    3.4,
#    2.4,
#    'bet365',
#    'William Hill',
#    'Pinnacle Sports',
#    8,
#    8,
#    8),
#   1),
#  (('England: Nationwide Conference',
#    '2005-01-08',
#    'Leigh Genesis',
#    0,
#    'Ebbsfleet',
#    1,
#    2.9438,
#    3.3125,
#    2.1063,
#    3.25,
#    3.4,
#    2.2,
#    'bet365',
#    'Coral',
#    'Ladbrokes',
#    8,
#    8,
#    8),
#   1),
#  (('England: Nationwide Conference',
#    '2005-01-08',
#    'Morecambe',
#    4,
#    'Canvey',
#    0,
#    1.705,
#    3.41,
#    4.235,
#    1.8,
#    3.53,
#    4.5,
#    'William Hill',
#    'Pinnacle Sports',
#    'Coral',
#    8,
#    8,
#    8),
#   1),
#  (('England: FA Cup',
#    '2005-01-08',
#    'Wolves',
#    2,
#    'Millwall',
#    0,
#    2.0333,
#    3.2222,
#    3.2389,
#    2.1,
#    3.3,
#    3.65,
#    'bet-at-home',
#    'Expekt',
#    'Pinnacle Sports',
#    9,
#    9,
#    9),
#   1),
#  (('England: FA Cup',
#    '2005-01-08',
#    'Derby',
#    2,
#    'Wigan',
#    1,
#    2.4889,
#    3.1822,
#    2.52,
#    2.6,
#    3.25,
#    2.85,
#    'Coral',
#    'Ladbrokes',
#    'Pinnacle Sports',
#    9,
#    9,
#    9),
#   1),
#  (('England: FA Cup',
#    '2005-01-08',
#    'Oldham',
#    1,
#    'Manchester City',
#    0,
#    5.4722,
#    3.5333,
#    1.5367,
#    6.0,
#    3.75,
#    1.57,
#    'Ladbrokes',
#    'Pinnacle Sports',
#    'Coral',
#    9,
#    9,
#    9),
#   1),
#  (('England: FA Cup',
#    '2005-01-08',
#    'Watford',
#    1,
#    'Fulham',
#    1,
#    3.1256,
#    3.1933,
#    2.0867,
#    3.28,
#    3.25,
#    2.23,
#    'Pinnacle Sports',
#    'bet365',
#    'Pinnacle Sports',
#    9,
#    9,
#    9),
#   1),
#  (('France: Coupe de France',
#    '2005-01-08',
#    'Vesoul',
#    1,
#    'Clermont',
#    1,
#    5.145,
#    3.225,
#    1.635,
#    5.7,
#    3.25,
#    1.65,
#    'Pinnacle Sports',
#    'Pinnacle Sports',
#    'bet-at-home',
#    2,
#    2,
#    2),
#   1),
#  (('France: Coupe de France',
#    '2005-01-08',
#    'Gambsheim',
#    0,
#    'Toulouse',
#    3,
#    9.99,
#    6.0,
#    1.135,
#    9.99,
#    6.0,
#    1.14,
#    'bet-at-home',
#    'bet-at-home',
#    'bet-at-home',
#    2,
#    2,
#    2),
#   1),
#  (('France: Coupe de France',
#    '2005-01-08',
#    'Troyes',
#    1,
#    'Albi',
#    3,
#    1.225,
#    4.625,
#    9.99,
#    1.25,
#    5.0,
#    9.99,
#    'Pinnacle Sports',
#    'bet-at-home',
#    'bet-at-home',
#    2,
#    2,
#    2),
#   1),
#  (('France: Coupe de France',
#    '2005-01-08',
#    'FC Cournon',
#    0,
#    'Nantes',
#    3,
#    9.99,
#    6.0,
#    1.14,
#    9.99,
#    6.0,
#    1.14,
#    'bet-at-home',
#    'bet-at-home',
#    'bet-at-home',
#    2,
#    2,
#    2),
#   1),
#  (('Portugal: Liga de Honra',
#    '2005-01-08',
#    'UD Ovarense',
#    3,
#    'FC Maia',
#    2,
#    2.1,
#    3.1,
#    2.9,
#    2.1,
#    3.1,
#    2.9,
#    'bet-at-home',
#    'bet-at-home',
#    'bet-at-home',
#    1,
#    1,
#    1),
#   1),
#  (('Scotland: FA Cup',
#    '2005-01-08',
#    'Berwick',
#    0,
#    'Brechin',
#    3,
#    3.9711,
#    3.5611,
#    1.7056,
#    4.75,
#    3.6,
#    1.8,
#    'Pinnacle Sports',
#    'bet365',
#    'Ladbrokes',
#    9,
#    9,
#    9),
#   1),
#  (('Scotland: FA Cup',
#    '2005-01-08',
#    'Clyde',
#    3,
#    'Falkirk',
#    0,
#    2.6489,
#    3.4156,
#    2.2267,
#    2.85,
#    3.5,
#    2.4,
#    'Pinnacle Sports',
#    'Coral',
#    'Sportingbet',
#    9,
#    9,
#    9),
#   1),
#  (('Scotland: FA Cup',
#    '2005-01-08',
#    'East Fife',
#    0,
#    'Dunfermline',
#    0,
#    9.55,
#    5.3889,
#    1.1911,
#    9.99,
#    5.5,
#    1.2,
#    'bet365',
#    'bet365',
#    'bet-at-home',
#    9,
#    9,
#    9),
#   1),
#  (('Scotland: FA Cup',
#    '2005-01-08',
#    'Montrose',
#    1,
#    'Queen of South',
#    2,
#    4.95,
#    3.7033,
#    1.5511,
#    5.65,
#    4.0,
#    1.61,
#    'Expekt',
#    'Ladbrokes',
#    'Paddy Power',
#    9,
#    9,
#    9),
#   1),
#  (('Scotland: FA Cup',
#    '2005-01-08',
#    'St. Mirren',
#    3,
#    'Hamilton',
#    0,
#    1.93,
#    3.4944,
#    3.1833,
#    2.1,
#    3.6,
#    3.45,
#    'Ladbrokes',
#    'William Hill',
#    'Expekt',
#    9,
#    9,
#    9),
#   1),
#  (('Spain: Primera Division',
#    '2005-01-08',
#    'Valencia',
#    2,
#    'Levante',
#    1,
#    1.3889,
#    3.9278,
#    8.11,
#    1.45,
#    4.2,
#    9.99,
#    'Coral',
#    'bet-at-home',
#    'Expekt',
#    9,
#    9,
#    9),
#   1),
#  (('Spain: Segunda Division',
#    '2005-01-08',
#    'Salamanca',
#    4,
#    'Tenerife',
#    5,
#    2.2489,
#    2.62,
#    3.3822,
#    2.4,
#    2.75,
#    3.94,
#    'William Hill',
#    'Ladbrokes',
#    'Pinnacle Sports',
#    9,
#    9,
#    9),
#   1),
#  (('Wales: Premier',
#    '2005-01-08',
#    'Port Talbot',
#    0,
#    'Caernarfon',
#    0,
#    2.25,
#    3.39,
#    2.6,
#    2.25,
#    3.39,
#    2.6,
#    'bet365',
#    'bet365',
#    'bet365',
#    1,
#    1,
#    1),
#   1),
#  (('Belgium: EXQI League',
#    '2005-01-09',
#    'Vise',
#    0,
#    'Kortrijk',
#    1,
#    1.9,
#    3.3,
#    3.25,
#    1.9,
#    3.3,
#    3.25,
#    'bet-at-home',
#    'bet-at-home',
#    'bet-at-home',
#    1,
#    1,
#    1),
#   1),
#  (('Greece: Super League',
#    '2005-01-09',
#    'OFI Crete',
#    2,
#    'Ionikos',
#    0,
#    1.6817,
#    3.29,
#    4.5833,
#    1.73,
#    3.4,
#    5.75,
#    'Coral',
#    'Coral',
#    'Expekt',
#    6,
#    6,
#    6),
#   1),
#  (('Greece: Super League',
#    '2005-01-09',
#    'AEK',
#    1,
#    'Panathinaikos',
#    0,
#    2.8533,
#    3.075,
#    2.27,
#    3.1,
#    3.2,
#    2.38,
#    'Expekt',
#    'Coral',
#    'Coral',
#    6,
#    6,
#    6),
#   1),
#  (('Italy: Serie A',
#    '2005-01-09',
#    'Bologna',
#    3,
#    'Chievo',
#    1,
#    2.0456,
#    2.9389,
#    3.5444,
#    2.2,
#    3.0,
#    3.95,
#    'Pinnacle Sports',
#    'bet365',
#    'Expekt',
#    9,
#    9,
#    9),
#   1),
#  (('Italy: Serie A',
#    '2005-01-09',
#    'Juventus',
#    4,
#    'Livorno',
#    2,
#    1.2022,
#    5.1611,
#    9.99,
#    1.22,
#    5.95,
#    9.99,
#    'bet365',
#    'Expekt',
#    'bet-at-home',
#    9,
#    9,
#    9),
#   1),
#  (('Italy: Serie A',
#    '2005-01-09',
#    'Palermo',
#    0,
#    'AC Milan',
#    0,
#    4.9678,
#    3.1611,
#    1.7267,
#    6.0,
#    3.25,
#    1.8,
#    'bet365',
#    'bet365',
#    'Coral',
#    9,
#    9,
#    9),
#   1),
#  (('Italy: Serie B',
#    '2005-01-09',
#    'Catania',
#    1,
#    'Venezia',
#    1,
#    1.5329,
#    3.1643,
#    6.5286,
#    1.57,
#    3.3,
#    7.5,
#    'Sportingbet',
#    'Ladbrokes',
#    'Expekt',
#    7,
#    7,
#    7),
#   1),
#  (('Italy: Serie B',
#    '2005-01-09',
#    'Crotone',
#    3,
#    'Pescara',
#    0,
#    2.0929,
#    2.7057,
#    3.7714,
#    2.2,
#    2.87,
#    4.2,
#    'Coral',
#    'bet365',
#    'Ladbrokes',
#    7,
#    7,
#    7),
#   1),
#  (('Italy: Serie B',
#    '2005-01-09',
#    'Genoa',
#    1,
#    'Piacenza',
#    0,
#    1.57,
#    3.1,
#    6.1643,
#    1.62,
#    3.25,
#    7.0,
#    'Ladbrokes',
#    'Expekt',
#    'bet365',
#    7,
#    7,
#    7),
#   1),
#  (('Portugal: Primeira Liga',
#    '2005-01-09',
#    'Beira Mar',
#    1,
#    'Braga',
#    4,
#    2.6638,
#    3.1275,
#    2.395,
#    3.06,
#    3.2,
#    2.5,
#    'Pinnacle Sports',
#    'bet-at-home',
#    'bet365',
#    8,
#    8,
#    8),
#   1),
#  (('Portugal: Primeira Liga',
#    '2005-01-09',
#    'Belenenses',
#    0,
#    'Gil Vicente',
#    1,
#    1.8588,
#    3.1625,
#    3.8063,
#    1.91,
#    3.3,
#    4.0,
#    'Pinnacle Sports',
#    'bet-at-home',
#    'Coral',
#    8,
#    8,
#    8),
#   1),
#  (('Portugal: Primeira Liga',
#    '2005-01-09',
#    'Penafiel',
#    0,
#    'Nacional',
#    1,
#    2.0213,
#    3.0975,
#    3.4,
#    2.29,
#    3.2,
#    3.75,
#    'Pinnacle Sports',
#    'Coral',
#    'bet365',
#    8,
#    8,
#    8),
#   1),
#  (('Portugal: Liga de Honra',
#    '2005-01-09',
#    'Gondomar',
#    0,
#    'FC Marco',
#    1,
#    2.35,
#    3.1,
#    2.54,
#    2.35,
#    3.1,
#    2.54,
#    'bet-at-home',
#    'bet-at-home',
#    'bet-at-home',
#    1,
#    1,
#    1),
#   1),
#  (('Portugal: Liga de Honra',
#    '2005-01-09',
#    'Varzim',
#    0,
#    'Feirense',
#    1,
#    1.85,
#    3.15,
#    3.6,
#    1.85,
#    3.15,
#    3.6,
#    'bet-at-home',
#    'bet-at-home',
#    'bet-at-home',
#    1,
#    1,
#    1),
#   1),
#  (('Portugal: Liga de Honra',
#    '2005-01-09',
#    'Ferreira',
#    3,
#    'Naval',
#    2,
#    1.9,
#    3.2,
#    3.3,
#    1.9,
#    3.2,
#    3.3,
#    'bet-at-home',
#    'bet-at-home',
#    'bet-at-home',
#    1,
#    1,
#    1),
#   1),
#  (('Portugal: Liga de Honra',
#    '2005-01-09',
#    'Santa Clara',
#    0,
#    'Amadora',
#    0,
#    2.54,
#    2.95,
#    2.45,
#    2.54,
#    2.95,
#    2.45,
#    'bet-at-home',
#    'bet-at-home',
#    'bet-at-home',
#    1,
#    1,
#    1),
#   1),
#  (('Spain: Primera Division',
#    '2005-01-09',
#    'Espanyol',
#    4,
#    'Osasuna',
#    1,
#    1.8833,
#    3.2111,
#    3.75,
#    2.0,
#    3.25,
#    4.0,
#    'Expekt',
#    'bet-at-home',
#    'Coral',
#    9,
#    9,
#    9),
#   1),
#  (('Spain: Segunda Division',
#    '2005-01-09',
#    'Celta Vigo',
#    2,
#    'Xerez',
#    1,
#    1.7944,
#    2.7622,
#    4.8811,
#    1.89,
#    2.88,
#    5.28,
#    'Pinnacle Sports',
#    'Coral',
#    'Pinnacle Sports',
#    9,
#    9,
#    9),
#   1),
#  (('Spain: Segunda Division',
#    '2005-01-09',
#    'Ejido',
#    0,
#    'Valladolid',
#    3,
#    2.6911,
#    2.5878,
#    2.7267,
#    2.85,
#    2.75,
#    2.8,
#    'Expekt',
#    'Ladbrokes',
#    'bet-at-home',
#    9,
#    9,
#    9),
#   1),
#  (('France: Ligue 2',
#    '2005-01-10',
#    'Sedan',
#    2,
#    'Nancy',
#    0,
#    2.334,
#    2.734,
#    3.102,
#    2.43,
#    2.85,
#    3.35,
#    'Pinnacle Sports',
#    'Expekt',
#    'Expekt',
#    5,
#    5,
#    5),
#   1),
#  (('Italy: Serie B',
#    '2005-01-10',
#    'Arezzo',
#    1,
#    'Empoli',
#    1,
#    2.4414,
#    2.6771,
#    2.9786,
#    2.5,
#    2.75,
#    3.1,
#    'Coral',
#    'bet365',
#    'bet365',
#    7,
#    7,
#    7),
#   1),
#  (('England: League Two',
#    '2005-01-11',
#    'Mansfield',
#    0,
#    'Cambridge Utd',
#    0,
#    1.595,
#    3.439,
#    5.09,
#    1.65,
#    3.5,
#    6.25,
#    'BetVictor',
#    'Coral',
#    'Pinnacle Sports',
#    10,
#    10,
#    10),
#   1),
#  (('France: Ligue 2',
#    '2005-01-11',
#    'Gueugnon',
#    2,
#    'Clermont',
#    0,
#    1.8786,
#    2.7343,
#    4.5886,
#    1.91,
#    2.8,
#    5.16,
#    'Ladbrokes',
#    'Expekt',
#    'Pinnacle Sports',
#    7,
#    7,
#    7),
#   1),
#  (('France: Ligue 2',
#    '2005-01-11',
#    'Laval',
#    1,
#    'Reims',
#    2,
#    1.85,
#    2.8257,
#    4.4914,
#    1.91,
#    2.9,
#    5.04,
#    'Ladbrokes',
#    'Expekt',
#    'Pinnacle Sports',
#    7,
#    7,
#    7),
#   1),
#  (('France: Ligue 2',
#    '2005-01-11',
#    'Le Mans',
#    1,
#    'Creteil',
#    0,
#    1.7029,
#    2.9457,
#    5.2657,
#    1.75,
#    3.21,
#    5.75,
#    'Sportingbet',
#    'Pinnacle Sports',
#    'Expekt',
#    7,
#    7,
#    7),
#   1),
#  (('France: Ligue 2',
#    '2005-01-11',
#    'Montpellier',
#    2,
#    'Angers',
#    1,
#    1.6971,
#    2.9414,
#    5.2957,
#    1.75,
#    3.1,
#    6.25,
#    'Sportingbet',
#    'Expekt',
#    'Expekt',
#    7,
#    7,
#    7),
#   1),
#  (('Spain: Copa del Rey',
#    '2005-01-11',
#    'Recreativo Huelva',
#    0,
#    'Sevilla',
#    2,
#    3.3125,
#    3.1438,
#    1.9963,
#    3.75,
#    3.2,
#    2.1,
#    'William Hill',
#    'Coral',
#    'bet-at-home',
#    8,
#    8,
#    8),
#   1),
#  (('France: Ligue 1',
#    '2005-01-12',
#    'Bastia',
#    0,
#    'Nantes',
#    0,
#    2.1967,
#    2.8844,
#    3.2556,
#    2.37,
#    3.0,
#    3.65,
#    'Pinnacle Sports',
#    'bet365',
#    'Expekt',
#    9,
#    9,
#    9),
#   1),
#  (('France: Ligue 1',
#    '2005-01-12',
#    'Metz',
#    1,
#    'AC Ajaccio',
#    0,
#    1.8178,
#    2.9211,
#    4.6256,
#    1.91,
#    3.1,
#    5.0,
#    'Ladbrokes',
#    'Expekt',
#    'Coral',
#    9,
#    9,
#    9),
#   1),
#  (('Greece: Greek Cup',
#    '2005-01-12',
#    'Aris',
#    3,
#    'Atromitos',
#    0,
#    1.075,
#    7.6,
#    9.99,
#    1.1,
#    9.0,
#    9.99,
#    'bet-at-home',
#    'Expekt',
#    'bet-at-home',
#    2,
#    2,
#    2),
#   1),
#  (('Italy: Coppa Italia',
#    '2005-01-12',
#    'AC Milan',
#    2,
#    'Palermo',
#    0,
#    1.425,
#    3.7188,
#    6.775,
#    1.45,
#    3.85,
#    8.0,
#    'bet-at-home',
#    'Expekt',
#    'Ladbrokes',
#    8,
#    8,
#    8),
#   1),
#  (('France: Ligue 2',
#    '2005-01-14',
#    'Angers',
#    2,
#    'Dijon',
#    2,
#    2.2889,
#    2.7078,
#    3.1856,
#    2.37,
#    2.8,
#    3.35,
#    'bet365',
#    'Ladbrokes',
#    'Expekt',
#    9,
#    9,
#    9),
#   1),
#  (('France: Ligue 2',
#    '2005-01-14',
#    'Clermont',
#    0,
#    'Le Havre',
#    1,
#    1.9,
#    2.8878,
#    4.0978,
#    2.1,
#    3.0,
#    4.5,
#    'Expekt',
#    'Expekt',
#    'Paddy Power',
#    9,
#    9,
#    9),
#   1),
#  (('Belgium: EXQI League',
#    '2005-01-15',
#    'Heusden-Zolder',
#    0,
#    'Eupen',
#    4,
#    1.7,
#    3.4,
#    3.9,
#    1.7,
#    3.4,
#    3.9,
#    'bet-at-home',
#    'bet-at-home',
#    'bet-at-home',
#    1,
#    1,
#    1),
#   1),
#  (('England: Premier League',
#    '2005-01-15',
#    'Liverpool',
#    0,
#    'Manchester United',
#    1,
#    2.617,
#    3.095,
#    2.586,
#    2.88,
#    3.2,
#    2.9,
#    'Paddy Power',
#    'bet365',
#    'Pinnacle Sports',
#    10,
#    10,
#    10),
#   1),
#  (('England: Premier League',
#    '2005-01-15',
#    'Aston Villa',
#    3,
#    'Norwich',
#    0,
#    1.661,
#    3.355,
#    5.157,
#    1.72,
#    3.46,
#    6.04,
#    'bet365',
#    'Pinnacle Sports',
#    'Pinnacle Sports',
#    10,
#    10,
#    10),
#   1),
#  (('England: Premier League',
#    '2005-01-15',
#    'Charlton',
#    3,
#    'Birmingham',
#    1,
#    2.063,
#    3.158,
#    3.409,
#    2.2,
#    3.25,
#    3.6,
#    'bet365',
#    'BetVictor',
#    'BetVictor',
#    10,
#    10,
#    10),
#   1),
#  (('England: Premier League',
#    '2005-01-15',
#    'Manchester City',
#    3,
#    'Crystal Palace',
#    1,
#    1.636,
#    3.418,
#    5.183,
#    1.67,
#    3.6,
#    6.0,
#    'Coral',
#    'bet365',
#    'Expekt',
#    10,
#    10,
#    10),
#   1),
#  (('England: Championship',
#    '2005-01-15',
#    'Gillingham FC',
#    1,
#    'Plymouth',
#    0,
#    2.2822,
#    3.2267,
#    2.76,
#    2.47,
#    3.29,
#    2.9,
#    'Pinnacle Sports',
#    'Pinnacle Sports',
#    'Expekt',
#    9,
#    9,
#    9),
#   1),
#  (('England: League One',
#    '2005-01-15',
#    'Barnsley',
#    4,
#    'Huddersfield',
#    2,
#    1.989,
#    3.234,
#    3.314,
#    2.1,
#    3.54,
#    3.65,
#    'Coral',
#    'Pinnacle Sports',
#    'Pinnacle Sports',
#    10,
#    10,
#    10),
#   1),
#  (('England: League One',
#    '2005-01-15',
#    'Bournemouth',
#    1,
#    'Sheffield Wed',
#    1,
#    2.385,
#    3.218,
#    2.606,
#    2.5,
#    3.33,
#    2.75,
#    'BetVictor',
#    'Pinnacle Sports',
#    'Ladbrokes',
#    10,
#    10,
#    10),
#   1),
#  (('England: League One',
#    '2005-01-15',
#    'Bristol City',
#    0,
#    'Bradford',
#    0,
#    1.732,
#    3.379,
#    4.17,
#    1.83,
#    3.74,
#    4.7,
#    'Paddy Power',
#    'Pinnacle Sports',
#    'Pinnacle Sports',
#    10,
#    10,
#    10),
#   1),
#  (('England: League One',
#    '2005-01-15',
#    'Hull City',
#    2,
#    'Peterborough',
#    2,
#    1.374,
#    3.985,
#    7.341,
#    1.4,
#    4.45,
#    8.5,
#    'Coral',
#    'Pinnacle Sports',
#    'Expekt',
#    10,
#    10,
#    10),
#   1),
#  (('England: League One',
#    '2005-01-15',
#    'Luton',
#    3,
#    'Stockport',
#    0,
#    1.4,
#    3.84,
#    7.115,
#    1.45,
#    4.0,
#    7.75,
#    'Coral',
#    'bet365',
#    'Expekt',
#    10,
#    10,
#    10),
#   1),
#  (('England: League Two',
#    '2005-01-15',
#    'Shrewsbury',
#    0,
#    'Boston',
#    0,
#    2.31,
#    3.209,
#    2.707,
#    2.4,
#    3.29,
#    2.79,
#    'BetVictor',
#    'Pinnacle Sports',
#    'bet365',
#    10,
#    10,
#    10),
#   1),
#  (('England: League Two',
#    '2005-01-15',
#    'Swansea',
#    2,
#    'Wycombe',
#    2,
#    1.635,
#    3.429,
#    4.718,
#    1.67,
#    3.64,
#    5.15,
#    'Ladbrokes',
#    'Pinnacle Sports',
#    'Expekt',
#    10,
#    10,
#    10),
#   1),
#  (('France: Ligue 1',
#    '2005-01-15',
#    'Auxerre',
#    2,
#    'Sochaux',
#    0,
#    1.804,
#    2.972,
#    4.558,
#    1.9,
#    3.2,
#    5.6,
#    'Pinnacle Sports',
#    'Ladbrokes',
#    'Expekt',
#    10,
#    10,
#    10),
#   1),
#  (('France: Ligue 1',
#    '2005-01-15',
#    'Lens',
#    0,
#    'Istres',
#    1,
#    1.556,
#    3.2,
#    6.373,
#    1.61,
#    3.6,
#    8.75,
#    'Paddy Power',
#    'Expekt',
#    'Expekt',
#    10,
#    10,
#    10),
#   1),
#  (('Greece: Super League',
#    '2005-01-15',
#    'PAE Egaleo',
#    2,
#    'PAOK',
#    1,
#    2.3243,
#    2.9929,
#    2.8,
#    2.5,
#    3.2,
#    3.1,
#    'William Hill',
#    'BetVictor',
#    'bet-at-home',
#    7,
#    7,
#    7),
#   1),
#  (('Portugal: Primeira Liga',
#    '2005-01-15',
#    'Academica',
#    0,
#    'FC Porto',
#    0,
#    5.518,
#    3.508,
#    1.534,
#    6.75,
#    3.7,
#    1.6,
#    'Expekt',
#    'Expekt',
#    'BetVictor',
#    10,
#    10,
#    10),
#   1),
#  (('Scotland: Premier League',
#    '2005-01-15',
#    'Livingston',
#    0,
#    'Hibernian',
#    2,
#    2.878,
#    3.272,
#    2.163,
#    3.0,
#    3.39,
#    2.25,
#    'bet365',
#    'bet365',
#    'Coral',
#    10,
#    10,
#    10),
#   1),
#  (('Scotland: Division 1',
#    '2005-01-15',
#    'Partick',
#    3,
#    'Queen of South',
#    1,
#    2.16,
#    3.496,
#    2.682,
#    2.25,
#    3.71,
#    2.88,
#    'bet-at-home',
#    'Pinnacle Sports',
#    'Sportingbet',
#    10,
#    10,
#    10),
#   1),
#  (('Scotland: Division 2',
#    '2005-01-15',
#    'Forfar Athletic',
#    4,
#    'Stirling',
#    1,
#    2.3525,
#    3.55,
#    2.4038,
#    2.5,
#    3.7,
#    2.57,
#    'Ladbrokes',
#    'Pinnacle Sports',
#    'Pinnacle Sports',
#    8,
#    8,
#    8),
#   1),
#  (('Scotland: Division 3',
#    '2005-01-15',
#    'East Stirlingshire',
#    0,
#    'Elgin City',
#    3,
#    2.7313,
#    3.5125,
#    2.125,
#    2.9,
#    3.6,
#    2.25,
#    'Paddy Power',
#    'BetVictor',
#    'Ladbrokes',
#    8,
#    8,
#    8),
#   1),
#  (('Spain: Primera Division',
#    '2005-01-15',
#    'Getafe',
#    1,
#    'Atl. Madrid',
#    1,
#    2.519,
#    3.15,
#    2.554,
#    2.75,
#    3.2,
#    2.75,
#    'Pinnacle Sports',
#    'bet365',
#    'Ladbrokes',
#    10,
#    10,
#    10),
#   1),
#  (('Spain: Segunda Division',
#    '2005-01-15',
#    'Almeria',
#    1,
#    'Recreativo Huelva',
#    0,
#    2.4056,
#    2.6756,
#    3.0044,
#    2.5,
#    2.8,
#    3.24,
#    'bet-at-home',
#    'BetVictor',
#    'Pinnacle Sports',
#    9,
#    9,
#    9),
#   1),
#  (('Spain: Segunda Division',
#    '2005-01-15',
#    'Eibar',
#    2,
#    'Celta Vigo',
#    1,
#    2.5289,
#    2.6844,
#    2.8133,
#    2.65,
#    2.8,
#    3.0,
#    'Expekt',
#    'Ladbrokes',
#    'bet-at-home',
#    9,
#    9,
#    9),
#   1),
#  (('Wales: Premier',
#    '2005-01-15',
#    'Airbus',
#    1,
#    'Haverfordwest',
#    2,
#    5.0,
#    3.5,
#    1.57,
#    5.0,
#    3.5,
#    1.57,
#    'bet365',
#    'bet365',
#    'bet365',
#    1,
#    1,
#    1),
#   1),
#  (('Wales: Premier',
#    '2005-01-15',
#    'Caernarfon',
#    0,
#    'TNS',
#    7,
#    8.0,
#    5.0,
#    1.25,
#    8.0,
#    5.0,
#    1.25,
#    'bet365',
#    'bet365',
#    'bet365',
#    1,
#    1,
#    1),
#   1),
#  (('Wales: Premier',
#    '2005-01-15',
#    'Carmarthen Town',
#    1,
#    'Druids',
#    1,
#    1.44,
#    3.6,
#    6.5,
#    1.44,
#    3.6,
#    6.5,
#    'bet365',
#    'bet365',
#    'bet365',
#    1,
#    1,
#    1),
#   1),
#  (('Italy: Serie A',
#    '2005-01-16',
#    'Parma',
#    2,
#    'Lecce',
#    1,
#    1.943,
#    3.093,
#    3.69,
#    2.04,
#    3.25,
#    4.2,
#    'William Hill',
#    'bet-at-home',
#    'Expekt',
#    10,
#    10,
#    10),
#   1),
#  (('Italy: Serie B',
#    '2005-01-16',
#    'Catanzaro',
#    1,
#    'Ternana',
#    4,
#    2.2225,
#    2.7375,
#    3.2563,
#    2.29,
#    2.8,
#    3.5,
#    'Expekt',
#    'Ladbrokes',
#    'BetVictor',
#    8,
#    8,
#    8),
#   1),
#  (('Mexico: Primera Division',
#    '2005-01-16',
#    'Dorados de Sinaloa',
#    0,
#    'Club America',
#    1,
#    2.4633,
#    3.1,
#    2.44,
#    2.54,
#    3.25,
#    2.6,
#    'Expekt',
#    'bet365',
#    'bet-at-home',
#    3,
#    3,
#    3),
#   1),
#  (('Mexico: Primera Division',
#    '2005-01-16',
#    'U.A.N.L.- Tigres',
#    0,
#    'Chiapas',
#    0,
#    1.6867,
#    3.3633,
#    4.0767,
#    1.7,
#    3.39,
#    4.33,
#    'bet-at-home',
#    'bet365',
#    'bet365',
#    3,
#    3,
#    3),
#   1),
#  (('Portugal: Liga de Honra',
#    '2005-01-16',
#    'Leixoes',
#    0,
#    'Gondomar',
#    1,
#    1.8,
#    3.3,
#    3.6,
#    1.8,
#    3.3,
#    3.6,
#    'bet-at-home',
#    'bet-at-home',
#    'bet-at-home',
#    1,
#    1,
#    1),
#   1),
#  (('Spain: Primera Division',
#    '2005-01-16',
#    'Albacete',
#    0,
#    'Santander',
#    0,
#    1.941,
#    3.205,
#    3.55,
#    2.0,
#    3.25,
#    4.0,
#    'bet365',
#    'bet365',
#    'bet-at-home',
#    10,
#    10,
#    10),
#   1),
#  (('Spain: Primera Division',
#    '2005-01-16',
#    'Betis',
#    2,
#    'Mallorca',
#    0,
#    1.6,
#    3.399,
#    5.269,
#    1.67,
#    3.5,
#    5.5,
#    'Coral',
#    'Ladbrokes',
#    'bet365',
#    10,
#    10,
#    10),
#   1),
#  (('Spain: Primera Division',
#    '2005-01-16',
#    'Barcelona',
#    1,
#    'Real Sociedad',
#    0,
#    1.33,
#    4.2089,
#    8.8089,
#    1.37,
#    4.5,
#    9.75,
#    'Coral',
#    'bet365',
#    'Expekt',
#    9,
#    9,
#    9),
#   1),
#  (('Spain: Segunda Division',
#    '2005-01-16',
#    'Terrassa',
#    3,
#    'Cadiz',
#    2,
#    3.2611,
#    2.7,
#    2.2478,
#    3.6,
#    3.0,
#    2.35,
#    'Pinnacle Sports',
#    'Ladbrokes',
#    'bet-at-home',
#    9,
#    9,
#    9),
#   1),
#  (('Spain: Segunda Division',
#    '2005-01-16',
#    'Valladolid',
#    0,
#    'Cordoba',
#    1,
#    1.3289,
#    3.9644,
#    8.3989,
#    1.35,
#    4.33,
#    9.99,
#    'bet-at-home',
#    'Sportingbet',
#    'Ladbrokes',
#    9,
#    9,
#    9),
#   1),
#  (('England: FA Trophy',
#    '2005-01-17',
#    'Thurrock',
#    1,
#    'Aldershot',
#    0,
#    2.752,
#    3.43,
#    2.13,
#    2.89,
#    3.5,
#    2.25,
#    'bet365',
#    'bet365',
#    'Ladbrokes',
#    5,
#    5,
#    5),
#   1),
#  (('England: FA Cup',
#    '2005-01-18',
#    'Blackpool',
#    0,
#    'Leicester',
#    1,
#    3.1056,
#    3.2222,
#    2.0711,
#    3.25,
#    3.25,
#    2.2,
#    'bet365',
#    'bet365',
#    'Sportingbet',
#    9,
#    9,
#    9),
#   1),
#  (('England: FA Cup',
#    '2005-01-18',
#    'Burnley',
#    1,
#    'Liverpool',
#    0,
#    5.488,
#    3.5,
#    1.575,
#    6.25,
#    3.65,
#    1.72,
#    'Expekt',
#    'Expekt',
#    'bet365',
#    10,
#    10,
#    10),
#   1),
#  (('England: FA Trophy',
#    '2005-01-18',
#    'Accrington',
#    0,
#    'Hereford',
#    0,
#    2.55,
#    3.5,
#    2.25,
#    2.6,
#    3.6,
#    2.25,
#    'William Hill',
#    'bet365',
#    'bet365',
#    2,
#    2,
#    2),
#   1),
#  (('Northern Ireland: IFA Premiership',
#    '2005-01-18',
#    'Glentoran',
#    4,
#    'Ballymena',
#    2,
#    1.36,
#    4.0,
#    7.0,
#    1.36,
#    4.0,
#    7.0,
#    'Paddy Power',
#    'Paddy Power',
#    'Paddy Power',
#    1,
#    1,
#    1),
#   1),
#  (('Spain: Copa del Rey',
#    '2005-01-18',
#    'Sevilla',
#    2,
#    'Recreativo Huelva',
#    1,
#    1.4413,
#    3.6675,
#    6.4875,
#    1.5,
#    4.0,
#    7.0,
#    'bet-at-home',
#    'Paddy Power',
#    'BetVictor',
#    8,
#    8,
#    8),
#   1),
#  (('Belgium: EXQI League',
#    '2005-01-19',
#    'Patro Eisden',
#    0,
#    'Ronse',
#    0,
#    2.425,
#    3.1,
#    2.5,
#    2.5,
#    3.1,
#    2.5,
#    'Sportingbet',
#    'bet-at-home',
#    'bet-at-home',
#    2,
#    2,
#    2),
#   1),
#  (('Belgium: Belgian Cup',
#    '2005-01-19',
#    'Mouscron',
#    0,
#    'Gent',
#    1,
#    2.4188,
#    3.2575,
#    2.4888,
#    2.64,
#    3.4,
#    2.62,
#    'Pinnacle Sports',
#    'William Hill',
#    'Sportingbet',
#    8,
#    8,
#    8),
#   1),
#  (('Belgium: Belgian Cup',
#    '2005-01-19',
#    'St. Liege',
#    0,
#    'Charleroi',
#    0,
#    1.5438,
#    3.5313,
#    5.2663,
#    1.67,
#    3.95,
#    6.0,
#    'Sportingbet',
#    'Pinnacle Sports',
#    'BetVictor',
#    8,
#    8,
#    8),
#   1),
#  (('England: FA Cup',
#    '2005-01-19',
#    'Blackburn',
#    3,
#    'Cardiff',
#    2,
#    1.399,
#    3.85,
#    7.09,
#    1.45,
#    4.0,
#    8.0,
#    'Expekt',
#    'BetVictor',
#    'Ladbrokes',
#    10,
#    10,
#    10),
#   1),
#  (('Greece: Greek Cup',
#    '2005-01-19',
#    'AO Ilisiakos',
#    0,
#    'Panionios',
#    1,
#    3.8,
#    3.2,
#    1.8,
#    3.8,
#    3.2,
#    1.8,
#    'bet-at-home',
#    'bet-at-home',
#    'bet-at-home',
#    1,
#    1,
#    1),
#   1),
#  (('Italy: Serie A',
#    '2005-01-19',
#    'Messina',
#    1,
#    'Atalanta',
#    0,
#    1.776,
#    3.085,
#    4.525,
#    1.9,
#    3.2,
#    5.0,
#    'Pinnacle Sports',
#    'Coral',
#    'Paddy Power',
#    10,
#    10,
#    10),
#   1),
#  (('Spain: Copa del Rey',
#    '2005-01-19',
#    'Numancia',
#    1,
#    'Elche',
#    0,
#    1.8411,
#    3.2022,
#    3.8222,
#    1.9,
#    3.3,
#    4.5,
#    'Expekt',
#    'bet-at-home',
#    'Ladbrokes',
#    9,
#    9,
#    9),
#   1),
#  (('Spain: Copa del Rey',
#    '2005-01-19',
#    'Betis',
#    0,
#    'Mirandes',
#    0,
#    1.217,
#    5.02,
#    9.455,
#    1.25,
#    5.5,
#    9.99,
#    'bet-at-home',
#    'Paddy Power',
#    'bet365',
#    10,
#    10,
#    10),
#   1),
#  (('Spain: Copa del Rey',
#    '2005-01-20',
#    'Atl. Madrid',
#    2,
#    'Lorca Deportiva',
#    0,
#    1.217,
#    4.978,
#    9.481,
#    1.25,
#    5.5,
#    9.99,
#    'bet-at-home',
#    'William Hill',
#    'Coral',
#    10,
#    10,
#    10),
#   1),
#  (('Chile: Primera Division',
#    '2005-01-21',
#    'Huachipato',
#    4,
#    'La Serena',
#    1,
#    1.75,
#    3.3,
#    4.0,
#    1.75,
#    3.3,
#    4.0,
#    'Sportingbet',
#    'Sportingbet',
#    'Sportingbet',
#    1,
#    1,
#    1),
#   1),
#  (('France: Ligue 2',
#    '2005-01-21',
#    'Chateauroux',
#    2,
#    'Guingamp',
#    0,
#    2.07,
#    2.6322,
#    3.8944,
#    2.15,
#    2.75,
#    4.2,
#    'Expekt',
#    'Expekt',
#    'Pinnacle Sports',
#    9,
#    9,
#    9),
#   1),
#  (('France: Ligue 2',
#    '2005-01-21',
#    'Gueugnon',
#    1,
#    'Reims',
#    1,
#    1.9044,
#    2.7456,
#    4.3522,
#    1.95,
#    2.85,
#    4.59,
#    'Expekt',
#    'Expekt',
#    'Pinnacle Sports',
#    9,
#    9,
#    9),
#   1),
#  (('Germany: Bundesliga',
#    '2005-01-21',
#    'Bayern Munich',
#    3,
#    'Hamburger SV',
#    0,
#    1.421,
#    3.846,
#    6.84,
#    1.45,
#    4.0,
#    7.75,
#    'bet-at-home',
#    'bet365',
#    'Expekt',
#    10,
#    10,
#    10),
#   1),
#  (('Netherlands: Eredivisie',
#    '2005-01-21',
#    'AZ Alkmaar',
#    1,
#    'Nijmegen',
#    1,
#    1.285,
#    4.494,
#    8.334,
#    1.33,
#    4.75,
#    9.99,
#    'Coral',
#    'Expekt',
#    'bet-at-home',
#    10,
#    10,
#    10),
#   1),
#  (('Belgium: Jupiler League',
#    '2005-01-22',
#    'Mouscron',
#    1,
#    'Genk',
#    2,
#    2.625,
#    3.181,
#    2.358,
#    2.81,
#    3.25,
#    2.5,
#    'Pinnacle Sports',
#    'BetVictor',
#    'bet365',
#    10,
#    10,
#    10),
#   1),
#  (('Belgium: EXQI League',
#    '2005-01-22',
#    'Patro Eisden',
#    1,
#    'Tubize',
#    2,
#    2.1,
#    3.2,
#    2.9,
#    2.1,
#    3.2,
#    2.9,
#    'bet-at-home',
#    'bet-at-home',
#    'bet-at-home',
#    1,
#    1,
#    1),
#   1),
#  (('Chile: Primera Division',
#    '2005-01-22',
#    'Palestino',
#    3,
#    'Rangers',
#    1,
#    1.73,
#    3.3,
#    4.2,
#    1.73,
#    3.3,
#    4.2,
#    'Sportingbet',
#    'Sportingbet',
#    'Sportingbet',
#    1,
#    1,
#    1),
#   1),
#  (('England: Premier League',
#    '2005-01-22',
#    'Everton',
#    0,
#    'Charlton',
#    1,
#    1.83,
#    3.249,
#    4.17,
#    2.0,
#    3.3,
#    4.5,
#    'Pinnacle Sports',
#    'bet-at-home',
#    'BetVictor',
#    10,
#    10,
#    10),
#   1),
#  (('England: Premier League',
#    '2005-01-22',
#    'Manchester United',
#    3,
#    'Aston Villa',
#    1,
#    1.308,
#    4.424,
#    9.171,
#    1.34,
#    5.0,
#    9.99,
#    'Pinnacle Sports',
#    'BetVictor',
#    'bet-at-home',
#    10,
#    10,
#    10),
#   1),
#  (('England: Championship',
#    '2005-01-22',
#    'Brighton',
#    0,
#    'Nottingham',
#    0,
#    2.0422,
#    3.23,
#    3.2078,
#    2.27,
#    3.25,
#    3.5,
#    'Pinnacle Sports',
#    'bet365',
#    'Paddy Power',
#    9,
#    9,
#    9),
#   1),
#  (('England: Championship',
#    '2005-01-22',
#    'Cardiff',
#    2,
#    'Burnley',
#    0,
#    2.0356,
#    3.2222,
#    3.2356,
#    2.1,
#    3.25,
#    3.83,
#    'Coral',
#    'bet365',
#    'Pinnacle Sports',
#    9,
#    9,
#    9),
#   1),
#  (('England: Championship',
#    '2005-01-22',
#    'Millwall',
#    1,
#    'Wolves',
#    2,
#    1.9333,
#    3.2389,
#    3.5167,
#    2.1,
#    3.3,
#    3.75,
#    'Ladbrokes',
#    'Expekt',
#    'BetVictor',
#    9,
#    9,
#    9),
#   1),
#  (('England: League One',
#    '2005-01-22',
#    'Doncaster',
#    1,
#    'Hull City',
#    0,
#    2.689,
#    3.2,
#    2.335,
#    2.75,
#    3.25,
#    2.4,
#    'bet365',
#    'bet365',
#    'Expekt',
#    10,
#    10,
#    10),
#   1),
#  (('England: League Two',
#    '2005-01-22',
#    'Rushden',
#    2,
#    'Leyton Orient',
#    0,
#    2.529,
#    3.203,
#    2.469,
#    2.79,
#    3.33,
#    2.6,
#    'Pinnacle Sports',
#    'Pinnacle Sports',
#    'Expekt',
#    10,
#    10,
#    10),
#   1),
#  (('England: Nationwide Conference',
#    '2005-01-22',
#    'York',
#    1,
#    'Morecambe',
#    0,
#    2.5922,
#    3.2167,
#    2.3867,
#    2.75,
#    3.4,
#    2.5,
#    'Sportingbet',
#    'William Hill',
#    'BetVictor',
#    9,
#    9,
#    9),
#   1),
#  (('Germany: Bundesliga',
#    '2005-01-22',
#    'Mainz',
#    2,
#    'VfB Stuttgart',
#    3,
#    3.061,
#    3.217,
#    2.128,
#    3.3,
#    3.3,
#    2.2,
#    'Expekt',
#    'bet-at-home',
#    'bet365',
#    10,
#    10,
#    10),
#   1),
#  (('Germany: Bundesliga',
#    '2005-01-22',
#    'Schalke',
#    2,
#    'Werder Bremen',
#    1,
#    1.996,
#    3.245,
#    3.36,
#    2.13,
#    3.35,
#    3.75,
#    'Pinnacle Sports',
#    'Expekt',
#    'William Hill',
#    10,
#    10,
#    10),
#   1),
#  (('Germany: 2. Bundesliga',
#    '2005-01-22',
#    'Burghausen',
#    1,
#    'Karlsruher',
#    1,
#    1.765,
#    3.3438,
#    4.0413,
#    1.85,
#    3.5,
#    4.5,
#    'bet-at-home',
#    'bet365',
#    'bet365',
#    8,
#    8,
#    8),
#   1),
#  (('Germany: 2. Bundesliga',
#    '2005-01-22',
#    'Eintracht Trier',
#    2,
#    'Oberhausen',
#    2,
#    1.8225,
#    3.2863,
#    3.83,
#    1.9,
#    3.4,
#    4.09,
#    'bet-at-home',
#    'Pinnacle Sports',
#    'Pinnacle Sports',
#    8,
#    8,
#    8),
#   1),
#  (('Mexico: Primera Division',
#    '2005-01-22',
#    'Guadalajara Chivas',
#    0,
#    'Pachuca',
#    4,
#    1.9833,
#    3.2467,
#    3.1833,
#    2.0,
#    3.29,
#    3.25,
#    'bet365',
#    'bet365',
#    'William Hill',
#    3,
#    3,
#    3),
#   1),
#  (('Netherlands: Eredivisie',
#    '2005-01-22',
#    'Heerenveen',
#    2,
#    'Den Bosch',
#    1,
#    1.29,
#    4.467,
#    8.364,
#    1.33,
#    4.75,
#    9.99,
#    'William Hill',
#    'Expekt',
#    'BetVictor',
#    10,
#    10,
#    10),
#   1),
#  (('Northern Ireland: IFA Premiership',
#    '2005-01-22',
#    'Ballymena',
#    1,
#    'Dungannon',
#    2,
#    1.8,
#    3.25,
#    3.75,
#    1.8,
#    3.25,
#    3.75,
#    'Paddy Power',
#    'Paddy Power',
#    'Paddy Power',
#    1,
#    1,
#    1),
#   1),
#  (('Northern Ireland: IFA Premiership',
#    '2005-01-22',
#    'Lisburn',
#    2,
#    'Glentoran',
#    1,
#    5.0,
#    3.3,
#    1.61,
#    5.0,
#    3.3,
#    1.61,
#    'Paddy Power',
#    'Paddy Power',
#    'Paddy Power',
#    1,
#    1,
#    1),
#   1),
#  (('Northern Ireland: IFA Premiership',
#    '2005-01-22',
#    'Portadown',
#    4,
#    'Institute',
#    0,
#    1.36,
#    4.0,
#    7.0,
#    1.36,
#    4.0,
#    7.0,
#    'Paddy Power',
#    'Paddy Power',
#    'Paddy Power',
#    1,
#    1,
#    1),
#   1),
#  (('Portugal: Primeira Liga',
#    '2005-01-22',
#    'Nacional',
#    0,
#    'Boavista',
#    2,
#    2.044,
#    3.22,
#    3.191,
#    2.5,
#    3.3,
#    3.55,
#    'Paddy Power',
#    'William Hill',
#    'Pinnacle Sports',
#    10,
#    10,
#    10),
#   1),
#  (('Portugal: Primeira Liga',
#    '2005-01-22',
#    'Benfica',
#    0,
#    'Beira Mar',
#    2,
#    1.228,
#    5.025,
#    9.179,
#    1.25,
#    5.3,
#    9.99,
#    'Expekt',
#    'Pinnacle Sports',
#    'bet-at-home',
#    10,
#    10,
#    10),
#   1),
#  (('Portugal: Liga de Honra',
#    '2005-01-22',
#    'FC Maia',
#    1,
#    'Gondomar',
#    1,
#    1.7,
#    3.35,
#    4.15,
#    1.7,
#    3.35,
#    4.15,
#    'bet-at-home',
#    'bet-at-home',
#    'bet-at-home',
#    1,
#    1,
#    1),
#   1),
#  (('Scotland: Premier League',
#    '2005-01-22',
#    'Dundee FC',
#    1,
#    'Hearts',
#    1,
#    2.679,
#    3.223,
#    2.322,
#    2.85,
#    3.28,
#    2.4,
#    'Pinnacle Sports',
#    'Pinnacle Sports',
#    'Expekt',
#    10,
#    10,
#    10),
#   1),
#  (('Scotland: Division 3',
#    '2005-01-22',
#    "Queen's Park",
#    1,
#    'Montrose',
#    0,
#    2.1013,
#    3.4938,
#    2.8025,
#    2.2,
#    3.6,
#    3.1,
#    'Paddy Power',
#    'BetVictor',
#    'Sportingbet',
#    8,
#    8,
#    8),
#   1),
#  (('Spain: Segunda Division',
#    '2005-01-22',
#    'Cordoba',
#    2,
#    'Tenerife',
#    0,
#    2.522,
#    2.714,
#    2.781,
#    2.75,
#    2.92,
#    3.1,
#    'Coral',
#    'Pinnacle Sports',
#    'Expekt',
#    10,
#    10,
#    10),
#   1),
#  (('Spain: Segunda Division',
#    '2005-01-22',
#    'Elche',
#    3,
#    'Valladolid',
#    2,
#    2.209,
#    2.76,
#    3.241,
#    2.29,
#    2.86,
#    3.6,
#    'Pinnacle Sports',
#    'Pinnacle Sports',
#    'Expekt',
#    10,
#    10,
#    10),
#   1),
#  (('Chile: Primera Division',
#    '2005-01-23',
#    'Coquimbo',
#    2,
#    'D. Concepcion',
#    0,
#    1.6,
#    3.4,
#    4.75,
#    1.6,
#    3.4,
#    4.75,
#    'Sportingbet',
#    'Sportingbet',
#    'Sportingbet',
#    1,
#    1,
#    1),
#   1),
#  (('Germany: 2. Bundesliga',
#    '2005-01-23',
#    'Ahlen',
#    2,
#    'Greuther Furth',
#    4,
#    2.3863,
#    3.1313,
#    2.6613,
#    2.5,
#    3.25,
#    2.8,
#    'Expekt',
#    'BetVictor',
#    'Sportingbet',
#    8,
#    8,
#    8),
#   1),
#  (('Greece: Super League',
#    '2005-01-23',
#    'Ionikos',
#    0,
#    'Panathinaikos',
#    0,
#    7.8557,
#    3.9214,
#    1.3443,
#    9.99,
#    4.0,
#    1.36,
#    'Expekt',
#    'bet-at-home',
#    'Coral',
#    7,
#    7,
#    7),
#   1),
#  (('Italy: Serie A',
#    '2005-01-23',
#    'Messina',
#    1,
#    'Parma',
#    0,
#    2.202,
#    2.873,
#    3.286,
#    2.39,
#    3.0,
#    3.55,
#    'Pinnacle Sports',
#    'Ladbrokes',
#    'bet-at-home',
#    10,
#    10,
#    10),
#   1),
#  (('Italy: Serie A',
#    '2005-01-23',
#    'Siena',
#    0,
#    'Palermo',
#    0,
#    2.57,
#    2.795,
#    2.75,
#    2.75,
#    2.88,
#    3.05,
#    'Sportingbet',
#    'Paddy Power',
#    'Pinnacle Sports',
#    10,
#    10,
#    10),
#   1),
#  (('Italy: Serie A',
#    '2005-01-23',
#    'Fiorentina',
#    1,
#    'AS Roma',
#    2,
#    2.675,
#    2.89,
#    2.627,
#    2.75,
#    3.0,
#    2.85,
#    'bet-at-home',
#    'Ladbrokes',
#    'Expekt',
#    10,
#    10,
#    10),
#   1),
#  (('Italy: Serie B',
#    '2005-01-23',
#    'Triestina',
#    0,
#    'Cesena',
#    2,
#    1.9944,
#    2.7522,
#    3.9044,
#    2.0,
#    2.87,
#    4.25,
#    'bet365',
#    'bet365',
#    'Expekt',
#    9,
#    9,
#    9),
#   1),
#  (('Mexico: Primera Division',
#    '2005-01-23',
#    'Club America',
#    3,
#    'Estudiantes Tecos',
#    3,
#    1.576,
#    3.468,
#    4.818,
#    1.66,
#    3.6,
#    5.09,
#    'bet365',
#    'William Hill',
#    'Expekt',
#    5,
#    5,
#    5),
#   1),
#  (('Mexico: Primera Division',
#    '2005-01-23',
#    'Puebla',
#    5,
#    'Atlas',
#    2,
#    2.21,
#    3.18,
#    2.76,
#    2.25,
#    3.25,
#    2.8,
#    'bet365',
#    'bet365',
#    'bet-at-home',
#    5,
#    5,
#    5),
#   1),
#  (('Mexico: Primera Division',
#    '2005-01-23',
#    'Santos Laguna',
#    2,
#    'Dorados de Sinaloa',
#    1,
#    1.484,
#    3.63,
#    5.73,
#    1.57,
#    3.95,
#    7.0,
#    'bet365',
#    'Expekt',
#    'Expekt',
#    5,
#    5,
#    5),
#   1),
#  (('Netherlands: Eredivisie',
#    '2005-01-23',
#    'Feyenoord',
#    1,
#    'Vitesse',
#    2,
#    1.427,
#    3.78,
#    6.54,
#    1.46,
#    4.0,
#    7.5,
#    'Pinnacle Sports',
#    'Coral',
#    'Expekt',
#    10,
#    10,
#    10),
#   1),
#  (('Netherlands: Eredivisie',
#    '2005-01-23',
#    'Roosendaal',
#    0,
#    'Waalwijk',
#    1,
#    2.703,
#    3.233,
#    2.762,
#    3.01,
#    3.4,
#    7.0,
#    'Pinnacle Sports',
#    'BetVictor',
#    'Coral',
#    10,
#    10,
#    10),
#   1),
#  (('Portugal: Primeira Liga',
#    '2005-01-23',
#    'Rio Ave',
#    2,
#    'Estoril',
#    1,
#    1.645,
#    3.374,
#    4.678,
#    1.67,
#    3.5,
#    5.5,
#    'Coral',
#    'Pinnacle Sports',
#    'BetVictor',
#    10,
#    10,
#    10),
#   1),
#  (('Portugal: Primeira Liga',
#    '2005-01-23',
#    'Gil Vicente',
#    0,
#    'Sporting',
#    3,
#    4.3244,
#    3.2411,
#    1.7178,
#    4.7,
#    3.35,
#    1.83,
#    'bet-at-home',
#    'bet-at-home',
#    'bet365',
#    9,
#    9,
#    9),
#   1),
#  (('Portugal: Primeira Liga',
#    '2005-01-23',
#    'Leiria',
#    0,
#    'FC Porto',
#    1,
#    3.706,
#    3.184,
#    1.871,
#    4.09,
#    3.25,
#    1.91,
#    'Expekt',
#    'bet-at-home',
#    'Coral',
#    10,
#    10,
#    10),
#   1),
#  (('Portugal: Liga de Honra',
#    '2005-01-23',
#    'Chaves',
#    0,
#    'Felgueiras',
#    0,
#    2.1,
#    3.1,
#    3.0,
#    2.1,
#    3.1,
#    3.0,
#    'bet-at-home',
#    'bet-at-home',
#    'bet-at-home',
#    1,
#    1,
#    1),
#   1),
#  (('Spain: Primera Division',
#    '2005-01-23',
#    'Dep. La Coruna',
#    4,
#    'Espanyol',
#    1,
#    2.105,
#    3.184,
#    3.144,
#    2.25,
#    3.25,
#    3.45,
#    'Ladbrokes',
#    'bet-at-home',
#    'bet-at-home',
#    10,
#    10,
#    10),
#   1),
#  (('Spain: Primera Division',
#    '2005-01-23',
#    'Getafe',
#    3,
#    'Zaragoza',
#    0,
#    2.249,
#    3.158,
#    2.872,
#    2.35,
#    3.28,
#    3.2,
#    'Expekt',
#    'Pinnacle Sports',
#    'bet-at-home',
#    10,
#    10,
#    10),
#   1),
#  (('Spain: Segunda Division',
#    '2005-01-23',
#    'Gijon',
#    1,
#    'Alaves',
#    2,
#    2.664,
#    2.625,
#    2.72,
#    2.7,
#    2.8,
#    2.8,
#    'bet-at-home',
#    'Pinnacle Sports',
#    'Ladbrokes',
#    10,
#    10,
#    10),
#   1),
#  (('Spain: Segunda Division',
#    '2005-01-23',
#    'Murcia',
#    0,
#    'Almeria',
#    0,
#    2.315,
#    2.7,
#    3.137,
#    2.45,
#    2.9,
#    3.48,
#    'William Hill',
#    'BetVictor',
#    'Pinnacle Sports',
#    10,
#    10,
#    10),
#   1),
#  (('Turkey: Turkish Cup',
#    '2005-01-23',
#    'Trabzonspor',
#    2,
#    'Malatyaspor',
#    0,
#    1.348,
#    4.02,
#    7.5,
#    1.5,
#    4.3,
#    9.0,
#    'BetVictor',
#    'Expekt',
#    'Expekt',
#    5,
#    5,
#    5),
#   1),
#  (('England: Premier League',
#    '2005-01-24',
#    'Blackburn',
#    0,
#    'Bolton',
#    1,
#    2.25,
#    3.152,
#    3.003,
#    2.31,
#    3.25,
#    3.2,
#    'Pinnacle Sports',
#    'Paddy Power',
#    'bet-at-home',
#    10,
#    10,
#    10),
#   1),
#  (('England: League Two',
#    '2005-01-25',
#    'Notts County',
#    0,
#    'Macclesfield',
#    5,
#    2.233,
#    3.22,
#    2.797,
#    2.29,
#    3.3,
#    3.05,
#    'Paddy Power',
#    'Pinnacle Sports',
#    'Expekt',
#    10,
#    10,
#    10),
#   1),
#  (('England: League Two',
#    '2005-01-25',
#    'Yeovil',
#    2,
#    'Rochdale',
#    2,
#    1.512,
#    3.509,
#    5.94,
#    1.56,
#    3.6,
#    6.5,
#    'Pinnacle Sports',
#    'bet-at-home',
#    'bet365',
#    10,
#    10,
#    10),
#   1),
#  (('England: Nationwide Conference',
#    '2005-01-25',
#    'Halifax',
#    2,
#    'Burton',
#    0,
#    1.7156,
#    3.3767,
#    4.2222,
#    1.8,
#    3.45,
#    4.5,
#    'William Hill',
#    'Pinnacle Sports',
#    'bet365',
#    9,
#    9,
#    9),
#   1),
#  (('England: LDV Vans Trophy',
#    '2005-01-25',
#    'Hereford',
#    1,
#    'Wrexham',
#    2,
#    2.703,
#    3.309,
#    2.25,
#    2.88,
#    3.4,
#    2.37,
#    'Paddy Power',
#    'BetVictor',
#    'bet365',
#    10,
#    10,
#    10),
#   1),
#  (('England: LDV Vans Trophy',
#    '2005-01-25',
#    'Leyton Orient',
#    1,
#    'Bristol Rovers',
#    2,
#    2.13,
#    3.25,
#    2.94,
#    2.2,
#    3.4,
#    3.2,
#    'Coral',
#    'BetVictor',
#    'Sportingbet',
#    10,
#    10,
#    10),
#   1),
#  (('Netherlands: KNVB Beker',
#    '2005-01-25',
#    'Dordrecht',
#    1,
#    'Den Bosch',
#    3,
#    2.51,
#    3.225,
#    2.3875,
#    2.54,
#    3.25,
#    2.4,
#    'bet-at-home',
#    'Sportingbet',
#    'BetVictor',
#    4,
#    4,
#    4),
#   1),
#  (('Netherlands: KNVB Beker',
#    '2005-01-25',
#    'PSV',
#    4,
#    'Volendam',
#    0,
#    1.1,
#    6.875,
#    9.99,
#    1.1,
#    7.0,
#    9.99,
#    'bet-at-home',
#    'bet-at-home',
#    'bet-at-home',
#    4,
#    4,
#    4),
#   1),
#  (('Scotland: FA Cup',
#    '2005-01-25',
#    'Stranraer',
#    0,
#    'Ayr',
#    2,
#    1.732,
#    3.545,
#    3.83,
#    1.87,
#    3.6,
#    4.0,
#    'Pinnacle Sports',
#    'bet365',
#    'bet365',
#    10,
#    10,
# ...
#    'bet-at-home',
#    1,
#    1,
#    1),
#   1),
#  (('Portugal: Liga de Honra',
#    '2005-03-20',
#    'Amadora',
#    0,
#    'Leixoes',
#    1,
#    1.65,
#    3.35,
#    4.2,
#    1.65,
#    3.35,
#    4.2,
#    'bet-at-home',
#    'bet-at-home',
#    'bet-at-home',
#    1,
#    1,
#    1),
#   1),
#  (('Portugal: Liga de Honra',
#    '2005-03-20',
#    'Aves',
#    1,
#    'SC Espinho',
#    1,
#    1.65,
#    3.35,
#    4.2,
#    1.65,
#    3.35,
#    4.2,
#    'bet-at-home',
#    'bet-at-home',
#    'bet-at-home',
#    1,
#    1,
#    1),
#   1),
#  (('Portugal: Liga de Honra',
#    '2005-03-20',
#    'Ferreira',
#    4,
#    'Felgueiras',
#    1,
#    1.4,
#    3.8,
#    6.0,
#    1.4,
#    3.8,
#    6.0,
#    'bet-at-home',
#    'bet-at-home',
#    'bet-at-home',
#    1,
#    1,
#    1),
#   1),
#  (('Russia: Premier League',
#    '2005-03-20',
#    'Tomsk',
#    0,
#    'CSKA Moscow',
#    0,
#    4.2767,
#    3.3467,
#    1.66,
#    4.5,
#    3.39,
#    1.67,
#    'Sportingbet',
#    'bet365',
#    'Sportingbet',
#    3,
#    3,
#    3),
#   1),
#  (('Russia: Premier League',
#    '2005-03-20',
#    'Alania',
#    0,
#    'Zenit Petersburg',
#    3,
#    3.8833,
#    3.2167,
#    1.7667,
#    4.0,
#    3.25,
#    1.8,
#    'Sportingbet',
#    'bet365',
#    'bet365',
#    3,
#    3,
#    3),
#   1),
#  (('Singapore: S-League',
#    '2005-03-20',
#    'Balestier Khalsa',
#    3,
#    'Home Utd',
#    2,
#    6.0,
#    4.3,
#    1.4,
#    6.0,
#    4.3,
#    1.4,
#    'bwin',
#    'bwin',
#    'bwin',
#    1,
#    1,
#    1),
#   1),
#  (('Spain: Segunda Division',
#    '2005-03-20',
#    'Xerez',
#    3,
#    'Granada 74',
#    5,
#    1.8689,
#    2.88,
#    4.2133,
#    2.02,
#    3.0,
#    4.75,
#    'Pinnacle Sports',
#    'Ladbrokes',
#    'William Hill',
#    9,
#    9,
#    9),
#   1),
#  (('Switzerland: Super League',
#    '2005-03-20',
#    'Schaffhausen',
#    0,
#    'Thun',
#    1,
#    2.6444,
#    3.1556,
#    2.3878,
#    3.05,
#    3.25,
#    2.5,
#    'Pinnacle Sports',
#    'Expekt',
#    'bet365',
#    9,
#    9,
#    9),
#   1),
#  (('Switzerland: Super League',
#    '2005-03-20',
#    'Zurich',
#    2,
#    'Basel',
#    2,
#    2.7833,
#    3.2022,
#    2.2478,
#    3.1,
#    3.25,
#    2.35,
#    'Pinnacle Sports',
#    'BetVictor',
#    'Expekt',
#    9,
#    9,
#    9),
#   1),
#  (('Switzerland: Challenge League',
#    '2005-03-20',
#    'FC Baulmes',
#    2,
#    'Lugano',
#    0,
#    2.41,
#    3.2,
#    2.4,
#    2.54,
#    3.3,
#    2.5,
#    'bet-at-home',
#    'bet-at-home',
#    'Expekt',
#    3,
#    3,
#    3),
#   1),
#  (('Switzerland: Challenge League',
#    '2005-03-20',
#    'La Chaux-De-Fonds',
#    0,
#    'Meyrin',
#    2,
#    1.8,
#    3.25,
#    3.825,
#    1.85,
#    3.3,
#    3.9,
#    'Sportingbet',
#    'bet-at-home',
#    'bet-at-home',
#    2,
#    2,
#    2),
#   1),
#  (('Turkey: Super Lig',
#    '2005-03-20',
#    'Genclerbirligi',
#    2,
#    'Konyaspor',
#    1,
#    1.9418,
#    3.2618,
#    3.3982,
#    2.0,
#    3.4,
#    3.75,
#    'Coral',
#    'BetVictor',
#    'BetVictor',
#    11,
#    11,
#    11),
#   1),
#  (('Turkey: Bank Asya 1. Lig',
#    '2005-03-20',
#    'Mardinspor',
#    3,
#    'Karagumruk',
#    0,
#    1.46,
#    3.9633,
#    5.4833,
#    1.53,
#    4.2,
#    5.8,
#    'Sportingbet',
#    'William Hill',
#    'William Hill',
#    3,
#    3,
#    3),
#   1),
#  (('Turkey: Bank Asya 1. Lig',
#    '2005-03-20',
#    'Kocaelispor',
#    1,
#    'Dardanelspor',
#    0,
#    1.64,
#    3.5667,
#    4.35,
#    1.7,
#    3.6,
#    4.75,
#    'William Hill',
#    'Expekt',
#    'Sportingbet',
#    3,
#    3,
#    3),
#   1),
#  (('Czech Republic: Gambrinus liga',
#    '2005-03-21',
#    'Slovacko',
#    0,
#    'Teplice',
#    0,
#    2.188,
#    2.98,
#    2.95,
#    2.2,
#    3.0,
#    3.1,
#    'bet-at-home',
#    'bet-at-home',
#    'Expekt',
#    5,
#    5,
#    5),
#   1),
#  (('Netherlands: Eerste Divisie',
#    '2005-03-21',
#    'Helmond',
#    2,
#    'Dordrecht',
#    0,
#    1.8,
#    3.3633,
#    3.65,
#    1.85,
#    3.4,
#    3.75,
#    'Sportingbet',
#    'Sportingbet',
#    'bet365',
#    3,
#    3,
#    3),
#   1),
#  (('Portugal: Primeira Liga',
#    '2005-03-21',
#    'Sporting',
#    2,
#    'FC Porto',
#    0,
#    2.3145,
#    3.1155,
#    2.7555,
#    2.38,
#    3.2,
#    3.05,
#    'Coral',
#    'Coral',
#    'bet-at-home',
#    11,
#    11,
#    11),
#   1),
#  (('England: League One',
#    '2005-03-22',
#    'Blackpool',
#    2,
#    'Brentford',
#    1,
#    2.3018,
#    3.1918,
#    2.7236,
#    2.45,
#    3.25,
#    2.85,
#    'Pinnacle Sports',
#    'Sportingbet',
#    'Expekt',
#    11,
#    11,
#    11),
#   1),
#  (('Scotland: Division 3',
#    '2005-03-22',
#    'Cowdenbeath',
#    0,
#    'Stenhousemuir',
#    2,
#    2.0956,
#    3.4478,
#    2.8089,
#    2.25,
#    3.5,
#    3.0,
#    'William Hill',
#    'bet365',
#    'Ladbrokes',
#    9,
#    9,
#    9),
#   1),
#  (('Scotland: Division 3',
#    '2005-03-22',
#    'Elgin City',
#    1,
#    "Queen's Park",
#    0,
#    2.23,
#    3.4611,
#    2.6044,
#    2.34,
#    3.5,
#    2.8,
#    '10Bet',
#    'bet365',
#    'Pinnacle Sports',
#    9,
#    9,
#    9),
#   1),
#  (('Scotland: Division 3',
#    '2005-03-22',
#    'Albion Rovers',
#    0,
#    'East Fife',
#    6,
#    2.0733,
#    3.4656,
#    2.8456,
#    2.1,
#    3.55,
#    3.0,
#    'BetVictor',
#    'Pinnacle Sports',
#    'bet365',
#    9,
#    9,
#    9),
#   1),
#  (('Switzerland: Challenge League',
#    '2005-03-22',
#    'Luzern',
#    2,
#    'Bulle',
#    0,
#    1.225,
#    4.825,
#    9.25,
#    1.25,
#    4.9,
#    9.5,
#    'Sportingbet',
#    'bet-at-home',
#    'bet-at-home',
#    2,
#    2,
#    2),
#   1),
#  (('Wales: Premier',
#    '2005-03-22',
#    'Afan Lido',
#    0,
#    'Carmarthen Town',
#    2,
#    4.065,
#    3.34,
#    1.68,
#    4.33,
#    3.39,
#    1.7,
#    'bet365',
#    'bet365',
#    '10Bet',
#    2,
#    2,
#    2),
#   1),
#  (('Wales: Premier',
#    '2005-03-22',
#    'Haverfordwest',
#    1,
#    'Cwmbran Town',
#    0,
#    2.1,
#    3.2,
#    3.0,
#    2.1,
#    3.2,
#    3.0,
#    'bet365',
#    'bet365',
#    'bet365',
#    1,
#    1,
#    1),
#   1),
#  (('Brazil: Campeonato Paulista',
#    '2005-03-23',
#    'Corinthians',
#    2,
#    'Sao Caetano',
#    2,
#    1.5517,
#    3.4917,
#    4.9833,
#    1.57,
#    3.5,
#    5.5,
#    'bet365',
#    'bet-at-home',
#    'BetVictor',
#    6,
#    6,
#    6),
#   1),
#  (('Brazil: Campeonato Paulista',
#    '2005-03-23',
#    'Santo Andre',
#    3,
#    'Santos',
#    2,
#    3.3733,
#    3.2317,
#    1.8933,
#    3.6,
#    3.29,
#    1.95,
#    'Sportingbet',
#    'bet365',
#    'Expekt',
#    6,
#    6,
#    6),
#   1),
#  (('Brazil: Campeonato Paulista',
#    '2005-03-23',
#    'Uniao Barbarense',
#    1,
#    'Rio Branco SP',
#    1,
#    1.96,
#    3.2167,
#    3.2167,
#    2.1,
#    3.3,
#    3.5,
#    'Sportingbet',
#    'BetVictor',
#    'BetVictor',
#    6,
#    6,
#    6),
#   1),
#  (('Brazil: Campeonato Carioca',
#    '2005-03-23',
#    'Botafogo RJ',
#    3,
#    'Cabofriense',
#    3,
#    1.312,
#    4.172,
#    7.7,
#    1.33,
#    4.33,
#    8.0,
#    'bet365',
#    'Paddy Power',
#    'bet365',
#    5,
#    5,
#    5),
#   1),
#  (('Brazil: Campeonato Carioca',
#    '2005-03-23',
#    'Portuguesa RJ',
#    0,
#    'Madureira',
#    1,
#    1.566,
#    3.5,
#    4.94,
#    1.57,
#    3.5,
#    5.0,
#    'bet365',
#    'bet-at-home',
#    'bet365',
#    5,
#    5,
#    5),
#   1),
#  (('England: Nationwide Conference',
#    '2005-03-23',
#    'Woking',
#    1,
#    'Scarborough FC',
#    1,
#    1.679,
#    3.419,
#    4.361,
#    1.73,
#    3.6,
#    4.65,
#    'Coral',
#    'Sportingbet',
#    'Pinnacle Sports',
#    10,
#    10,
#    10),
#   1),
#  (('Germany: Regionalliga North',
#    '2005-03-23',
#    'St. Pauli',
#    1,
#    'Paderborn',
#    0,
#    2.476,
#    3.18,
#    2.458,
#    2.54,
#    3.25,
#    2.5,
#    '10Bet',
#    'Pinnacle Sports',
#    'Expekt',
#    5,
#    5,
#    5),
#   1),
#  (('Germany: Regionalliga North',
#    '2005-03-23',
#    'Uerdingen',
#    1,
#    'Preussen Munster',
#    3,
#    1.914,
#    3.32,
#    3.462,
#    2.2,
#    3.45,
#    4.16,
#    'Pinnacle Sports',
#    'Expekt',
#    '10Bet',
#    5,
#    5,
#    5),
#   1),
#  (('Germany: Regionalliga South',
#    '2005-03-23',
#    'Mainz II',
#    2,
#    'Stutt. Kickers',
#    1,
#    2.214,
#    3.15,
#    2.818,
#    2.29,
#    3.2,
#    3.05,
#    'Expekt',
#    'bet-at-home',
#    'Pinnacle Sports',
#    5,
#    5,
#    5),
#   1),
#  (('Northern Ireland: IFA Premiership',
#    '2005-03-23',
#    'Limavady',
#    0,
#    'Linfield',
#    1,
#    3.695,
#    3.325,
#    1.815,
#    4.0,
#    3.4,
#    1.9,
#    'Paddy Power',
#    'Paddy Power',
#    'bet365',
#    2,
#    2,
#    2),
#   1),
#  (('Poland: Orange Ekstraklasa',
#    '2005-03-23',
#    'Leczna',
#    1,
#    'Polonia Warszawa',
#    1,
#    1.675,
#    3.3,
#    4.365,
#    1.7,
#    3.35,
#    4.4,
#    'Sportingbet',
#    'bet-at-home',
#    'bet-at-home',
#    2,
#    2,
#    2),
#   1),
#  (('Switzerland: Challenge League',
#    '2005-03-23',
#    'Concordia',
#    1,
#    'Sion',
#    1,
#    3.55,
#    3.3,
#    1.85,
#    3.9,
#    3.4,
#    2.0,
#    'bet-at-home',
#    'bet-at-home',
#    'Sportingbet',
#    2,
#    2,
#    2),
#   1),
#  (('Wales: Premier',
#    '2005-03-23',
#    'Welshpool',
#    2,
#    'Caersws FC',
#    3,
#    3.2,
#    3.2,
#    2.0,
#    3.2,
#    3.2,
#    2.0,
#    'bet365',
#    'bet365',
#    'bet365',
#    1,
#    1,
#    1),
#   1),
#  (('Denmark: 1st Division',
#    '2005-03-24',
#    'Horsens',
#    2,
#    'Dalum IF',
#    1,
#    1.1729,
#    5.9443,
#    9.4214,
#    1.2,
#    6.45,
#    9.99,
#    'Ladbrokes',
#    'Expekt',
#    '10Bet',
#    7,
#    7,
#    7),
#   1),
#  (('Denmark: 2nd Division',
#    '2005-03-24',
#    'Brabrand',
#    2,
#    'Jetsmark',
#    0,
#    1.8325,
#    3.8125,
#    3.2875,
#    1.9,
#    4.0,
#    3.5,
#    'bet365',
#    'Expekt',
#    'Sportingbet',
#    4,
#    4,
#    4),
#   1),
#  (('Greece: Greek Cup',
#    '2005-03-24',
#    'Olympiakos Piraeus',
#    5,
#    'Kastoria',
#    1,
#    1.1033,
#    6.8167,
#    9.99,
#    1.11,
#    7.25,
#    9.99,
#    'Sportingbet',
#    'Expekt',
#    'bet-at-home',
#    3,
#    3,
#    3),
#   1),
#  (('Northern Ireland: IFA Premiership',
#    '2005-03-24',
#    'Ballymena',
#    2,
#    'Lisburn',
#    1,
#    2.15,
#    3.225,
#    2.875,
#    2.2,
#    3.25,
#    3.0,
#    'bet365',
#    'bet365',
#    'Paddy Power',
#    2,
#    2,
#    2),
#   1),
#  (('Northern Ireland: IFA Premiership',
#    '2005-03-24',
#    'Loughgall',
#    1,
#    'Coleraine',
#    5,
#    2.61,
#    3.245,
#    2.315,
#    2.62,
#    3.39,
#    2.38,
#    'Paddy Power',
#    'bet365',
#    'Paddy Power',
#    2,
#    2,
#    2),
#   1),
#  (('Poland: Polish Cup',
#    '2005-03-24',
#    'GKS Belchatow',
#    0,
#    'Plock',
#    1,
#    2.1,
#    3.15,
#    2.8,
#    2.1,
#    3.15,
#    2.8,
#    'bet-at-home',
#    'bet-at-home',
#    'bet-at-home',
#    1,
#    1,
#    1),
#   1),
#  (('Belgium: EXQI League',
#    '2005-03-25',
#    'Eupen',
#    1,
#    'FC Antwerp',
#    1,
#    2.4167,
#    3.15,
#    2.4667,
#    2.5,
#    3.2,
#    2.5,
#    'Sportingbet',
#    'bet-at-home',
#    'bet-at-home',
#    3,
#    3,
#    3),
#   1),
#  (('England: League One',
#    '2005-03-25',
#    'Luton',
#    1,
#    'Barnsley',
#    3,
#    1.475,
#    3.654,
#    6.444,
#    1.53,
#    3.8,
#    7.0,
#    'bet365',
#    'bet-at-home',
#    'Sportingbet',
#    10,
#    10,
#    10),
#   1),
#  (('England: League Two',
#    '2005-03-25',
#    'Southend',
#    3,
#    'Rochdale',
#    0,
#    1.697,
#    3.321,
#    4.39,
#    1.75,
#    3.4,
#    4.59,
#    'bet-at-home',
#    'BetVictor',
#    '10Bet',
#    10,
#    10,
#    10),
#   1),
#  (('England: Nationwide Conference',
#    '2005-03-25',
#    'Burton',
#    2,
#    'Accrington',
#    2,
#    2.559,
#    3.234,
#    2.399,
#    2.75,
#    3.3,
#    2.5,
#    'Expekt',
#    'Pinnacle Sports',
#    'BetVictor',
#    10,
#    10,
#    10),
#   1),
#  (('Europe: Euro U21',
#    '2005-03-25',
#    'Czech Republic U21',
#    3,
#    'Finland U21',
#    0,
#    1.25,
#    4.75,
#    9.0,
#    1.25,
#    5.0,
#    9.5,
#    'bet-at-home',
#    'Pinnacle Sports',
#    'Pinnacle Sports',
#    2,
#    2,
#    2),
#   1),
#  (('Europe: Euro U21',
#    '2005-03-25',
#    'Israel U21',
#    3,
#    'Ireland U21',
#    1,
#    2.4133,
#    3.05,
#    2.6367,
#    2.5,
#    3.2,
#    2.79,
#    'Pinnacle Sports',
#    '10Bet',
#    'Pinnacle Sports',
#    3,
#    3,
#    3),
#   1),
#  (('Europe: Euro U21',
#    '2005-03-25',
#    'Turkey U21',
#    4,
#    'Albania U21',
#    0,
#    1.1667,
#    4.6967,
#    9.6133,
#    1.25,
#    5.0,
#    9.99,
#    'Pinnacle Sports',
#    'bet-at-home',
#    'bet-at-home',
#    3,
#    3,
#    3),
#   1),
#  (('Europe: Euro U21',
#    '2005-03-25',
#    'Wales U21',
#    1,
#    'Austria U21',
#    0,
#    2.0489,
#    3.2,
#    3.1956,
#    2.2,
#    3.3,
#    3.66,
#    'Paddy Power',
#    'William Hill',
#    'Pinnacle Sports',
#    9,
#    9,
#    9),
#   1),
#  (('Europe: Euro U21',
#    '2005-03-25',
#    'England U21',
#    2,
#    'Germany U21',
#    2,
#    2.2067,
#    3.1644,
#    2.8856,
#    2.31,
#    3.25,
#    3.1,
#    'Pinnacle Sports',
#    'bet365',
#    'Sportingbet',
#    9,
#    9,
#    9),
#   1),
#  (('France: Ligue 2',
#    '2005-03-25',
#    'Creteil',
#    3,
#    'Montpellier',
#    3,
#    2.3,
#    2.8322,
#    3.0011,
#    2.5,
#    3.0,
#    3.46,
#    'bet365',
#    'Ladbrokes',
#    'Pinnacle Sports',
#    9,
#    9,
#    9),
#   1),
#  (('Ireland: Premier League',
#    '2005-03-25',
#    'Shamrock Rovers',
#    0,
#    'Shelbourne',
#    2,
#    3.5563,
#    3.175,
#    1.8775,
#    3.85,
#    3.2,
#    2.0,
#    'Expekt',
#    '10Bet',
#    'Sportingbet',
#    8,
#    8,
#    8),
#   1),
#  (('Netherlands: Eerste Divisie',
#    '2005-03-25',
#    'Haarlem',
#    0,
#    'Heracles',
#    1,
#    3.98,
#    3.3575,
#    1.6875,
#    4.33,
#    3.4,
#    1.85,
#    'bet365',
#    'Sportingbet',
#    'Sportingbet',
#    4,
#    4,
#    4),
#   1),
#  (('World: World Cup',
#    '2005-03-25',
#    'North Korea',
#    1,
#    'Bahrain',
#    2,
#    1.922,
#    3.2,
#    3.41,
#    2.0,
#    3.25,
#    3.5,
#    'Sportingbet',
#    'William Hill',
#    'BetVictor',
#    5,
#    5,
#    5),
#   1),
#  (('World: World Cup',
#    '2005-03-25',
#    'Iran',
#    2,
#    'Japan',
#    1,
#    2.3014,
#    3.1071,
#    2.7929,
#    2.5,
#    3.2,
#    3.0,
#    'bet365',
#    'Paddy Power',
#    'Ladbrokes',
#    7,
#    7,
#    7),
#   1),
#  (('Brazil: Campeonato Paulista',
#    '2005-03-26',
#    'Rio Branco SP',
#    1,
#    'Guarani',
#    2,
#    1.8333,
#    3.2667,
#    3.55,
#    1.85,
#    3.3,
#    3.75,
#    'Expekt',
#    'Expekt',
#    'Ladbrokes',
#    3,
#    3,
#    3),
#   1),
#  (('Brazil: Campeonato Paulista',
#    '2005-03-26',
#    'Santos',
#    1,
#    'Internacional',
#    0,
#    1.19,
#    5.1,
#    9.66,
#    1.2,
#    5.5,
#    9.99,
#    'Expekt',
#    'Ladbrokes',
#    'Ladbrokes',
#    3,
#    3,
#    3),
#   1),
#  (('Brazil: Campeonato Paulista',
#    '2005-03-26',
#    'Palmeiras',
#    4,
#    'Marilia',
#    1,
#    1.7167,
#    3.35,
#    4.0267,
#    1.75,
#    3.4,
#    4.33,
#    'Expekt',
#    'Ladbrokes',
#    'Ladbrokes',
#    3,
#    3,
#    3),
#   1),
#  (('England: League Two',
#    '2005-03-26',
#    'Notts County',
#    1,
#    'Bristol Rovers',
#    2,
#    2.2182,
#    3.1664,
#    2.8509,
#    2.27,
#    3.25,
#    3.1,
#    'Pinnacle Sports',
#    'BetVictor',
#    'Expekt',
#    11,
#    11,
#    11),
#   1),
#  (('England: League Two',
#    '2005-03-26',
#    'Boston',
#    1,
#    'Yeovil',
#    2,
#    2.6573,
#    3.2136,
#    2.3836,
#    2.75,
#    3.25,
#    2.54,
#    'bet365',
#    'BetVictor',
#    'Expekt',
#    11,
#    11,
#    11),
#   1),
#  (('Germany: Regionalliga North',
#    '2005-03-26',
#    'Arminia Bielefeld II',
#    1,
#    'St. Pauli',
#    4,
#    2.6325,
#    3.225,
#    2.3375,
#    2.75,
#    3.35,
#    2.4,
#    'Sportingbet',
#    'Expekt',
#    'Pinnacle Sports',
#    4,
#    4,
#    4),
#   1),
#  (('Germany: Regionalliga North',
#    '2005-03-26',
#    'Bremen II',
#    1,
#    'Wuppertaler',
#    3,
#    2.0,
#    3.25,
#    3.225,
#    2.15,
#    3.3,
#    3.45,
#    'Expekt',
#    'Sportingbet',
#    'Pinnacle Sports',
#    4,
#    4,
#    4),
#   1),
#  (('Germany: Regionalliga North',
#    '2005-03-26',
#    'Chemnitzer FC',
#    1,
#    'Holstein Kiel',
#    0,
#    1.985,
#    3.3375,
#    3.1775,
#    2.09,
#    3.45,
#    3.4,
#    'Pinnacle Sports',
#    'Expekt',
#    'Sportingbet',
#    4,
#    4,
#    4),
#   1),
#  (('Germany: Regionalliga South',
#    '2005-03-26',
#    'FC Nottingen',
#    1,
#    'Kickers Offenbach',
#    2,
#    5.2875,
#    3.6375,
#    1.53,
#    6.2,
#    3.75,
#    1.6,
#    'bet-at-home',
#    'Sportingbet',
#    'Expekt',
#    4,
#    4,
#    4),
#   1),
#  (('Italy: Serie B',
#    '2005-03-26',
#    'Treviso',
#    2,
#    'Vicenza',
#    0,
#    1.6263,
#    3.0425,
#    5.3838,
#    1.7,
#    3.25,
#    6.0,
#    'Sportingbet',
#    'bet365',
#    'BetVictor',
#    8,
#    8,
#    8),
#   1),
#  (('World: World Cup',
#    '2005-03-26',
#    'Georgia',
#    1,
#    'Greece',
#    3,
#    3.5136,
#    3.16,
#    1.9555,
#    4.0,
#    3.2,
#    2.19,
#    'Coral',
#    'bet-at-home',
#    'Pinnacle Sports',
#    11,
#    11,
#    11),
#   1),
#  (('World: World Cup',
#    '2005-03-26',
#    'Israel',
#    1,
#    'Ireland',
#    1,
#    2.9844,
#    3.14,
#    2.2367,
#    3.2,
#    3.2,
#    2.34,
#    'Expekt',
#    'bet365',
#    'Pinnacle Sports',
#    9,
#    9,
#    9),
#   1),
#  (('World: World Cup',
#    '2005-03-26',
#    'Belgium',
#    4,
#    'Bosnia &amp; Herzego',
#    1,
#    1.7273,
#    3.2918,
#    4.2827,
#    1.9,
#    3.4,
#    4.7,
#    'Pinnacle Sports',
#    'Ladbrokes',
#    'bet-at-home',
#    11,
#    11,
#    11),
#   1),
#  (('World: World Cup',
#    '2005-03-26',
#    'Bolivia',
#    1,
#    'Argentina',
#    2,
#    4.3,
#    3.25,
#    1.7125,
#    4.5,
#    3.4,
#    1.8,
#    'BetVictor',
#    'BetVictor',
#    'William Hill',
#    4,
#    4,
#    4),
#   1),
#  (('World: World Cup',
#    '2005-03-26',
#    'France',
#    0,
#    'Switzerland',
#    0,
#    1.321,
#    4.227,
#    8.55,
#    1.36,
#    4.5,
#    9.99,
#    'bet365',
#    'William Hill',
#    'Pinnacle Sports',
#    10,
#    10,
#    10),
#   1),
#  ...]

# %% [markdown]
# ## Save Results

# %%
matches_per_league_rdd \
    .map(lambda kv: f"{kv[0]},{kv[1]}") \
    .saveAsTextFile("./matches_per_league_txt")

# %% [markdown]
# # Spark DataFrame
#
# Spark DataFrame is a distributed collection of data organized into named columns, designed for efficient data manipulation and analysis in Apache Spark. It is used for various data processing tasks such as data ingestion, transformation, querying, and analysis in Apache Spark, providing a high-level abstraction that simplifies working with structured data.

# %% [markdown]
# ## Load Data into DataFrame

# %%
df = spark.read.format("csv") \
    .option("header",       "true") \
    .option("inferSchema",  "true") \
    .option("compression",  "gzip") \
    .load("./closing_odds.csv.gz")

# %% [markdown]
# ## View DataFrame Schema

# %%
df.printSchema()
# Out:
# root
#  |-- match_id: integer (nullable = true)
#  |-- league: string (nullable = true)
#  |-- match_date: date (nullable = true)
#  |-- home_team: string (nullable = true)
#  |-- home_score: integer (nullable = true)
#  |-- away_team: string (nullable = true)
#  |-- away_score: integer (nullable = true)
#  |-- avg_odds_home_win: double (nullable = true)
#  |-- avg_odds_draw: double (nullable = true)
#  |-- avg_odds_away_win: double (nullable = true)
#  |-- max_odds_home_win: double (nullable = true)
#  |-- max_odds_draw: double (nullable = true)
#  |-- max_odds_away_win: double (nullable = true)
#  |-- top_bookie_home_win: string (nullable = true)
#  |-- top_bookie_draw: string (nullable = true)
#  |-- top_bookie_away_win: string (nullable = true)
#  |-- n_odds_home_win: integer (nullable = true)
#  |-- n_odds_draw: integer (nullable = true)
#  |-- n_odds_away_win: integer (nullable = true)

# %% [markdown]
# ## View DataFrame Data

# %%
df.show(10)
# Out:
# +--------+--------------------+----------+---------------+----------+-----------------+----------+-----------------+-------------+-----------------+-----------------+-------------+-----------------+-------------------+---------------+-------------------+---------------+-----------+---------------+
# |match_id|              league|match_date|      home_team|home_score|        away_team|away_score|avg_odds_home_win|avg_odds_draw|avg_odds_away_win|max_odds_home_win|max_odds_draw|max_odds_away_win|top_bookie_home_win|top_bookie_draw|top_bookie_away_win|n_odds_home_win|n_odds_draw|n_odds_away_win|
# +--------+--------------------+----------+---------------+----------+-----------------+----------+-----------------+-------------+-----------------+-----------------+-------------+-----------------+-------------------+---------------+-------------------+---------------+-----------+---------------+
# |  170088|England: Premier ...|2005-01-01|      Liverpool|         0|          Chelsea|         1|           2.9944|       3.1944|           2.2256|              3.2|         3.25|             2.29|        Paddy Power|    Sportingbet|             Expekt|              9|          9|              9|
# |  170089|England: Premier ...|2005-01-01|         Fulham|         3|   Crystal Palace|         1|           1.9456|       3.2333|           3.6722|             2.04|          3.3|             4.15|    Pinnacle Sports|    bet-at-home|             Expekt|              9|          9|              9|
# |  170090|England: Premier ...|2005-01-01|    Aston Villa|         1|        Blackburn|         0|           1.8522|       3.2611|           4.0144|              2.0|          3.4|              4.5|    Pinnacle Sports|    Paddy Power|        Sportingbet|              9|          9|              9|
# |  170091|England: Premier ...|2005-01-01|         Bolton|         1|        West Brom|         1|           1.6122|       3.4133|           5.4722|             1.67|         3.57|             6.27|              Coral|Pinnacle Sports|    Pinnacle Sports|              9|          9|              9|
# |  170092|England: Premier ...|2005-01-01|       Charlton|         1|          Arsenal|         3|           5.9878|       3.4778|           1.5567|              7.0|          3.6|             1.62|             Expekt|    Paddy Power|             bet365|              9|          9|              9|
# |  170093|England: Premier ...|2005-01-01|Manchester City|         2|      Southampton|         1|              1.7|       3.3667|           4.7344|             1.73|          3.5|              5.0|             bet365|         Expekt|             bet365|              9|          9|              9|
# |  170094|England: Premier ...|2005-01-01|  Newcastle Utd|         2|       Birmingham|         1|           1.8622|         3.25|           3.9622|             1.91|          3.4|             4.33|             bet365|    Sportingbet|             bet365|              9|          9|              9|
# |  170095|England: Premier ...|2005-01-01|     Portsmouth|         1|          Norwich|         1|           1.6344|       3.3933|           5.2633|              1.7|         3.54|             6.14|       William Hill|Pinnacle Sports|    Pinnacle Sports|              9|          9|              9|
# |  170096|England: Premier ...|2005-01-01|      Tottenham|         5|          Everton|         2|           2.2156|       3.1722|           3.0444|             2.29|          3.2|             3.35|             Expekt|         bet365|    Pinnacle Sports|              9|          9|              9|
# |  170097|England: Premier ...|2005-01-01|  Middlesbrough|         0|Manchester United|         2|           3.3611|       3.2222|           2.0489|             3.75|         3.25|              2.1|             bet365|         Expekt|              Coral|              9|          9|              9|
# +--------+--------------------+----------+---------------+----------+-----------------+----------+-----------------+-------------+-----------------+-----------------+-------------+-----------------+-------------------+---------------+-------------------+---------------+-----------+---------------+
# only showing top 10 rows

# %% [markdown]
# ## Filter Data
#
# Performe a filter operation on a column

# %%
df_filtered = df.filter(df.avg_odds_home_win < 2.0)
df_filtered_united = df.filter(df.home_team.contains("United"))

df_filtered.select("league", "home_team", "away_team", "avg_odds_home_win").show(20)
df_filtered_united.select("league", "home_team", "home_score", "away_score", "away_team").show(20)
# Out:
# +--------------------+---------------+--------------+-----------------+
# |              league|      home_team|     away_team|avg_odds_home_win|
# +--------------------+---------------+--------------+-----------------+
# |England: Premier ...|         Fulham|Crystal Palace|           1.9456|
# |England: Premier ...|    Aston Villa|     Blackburn|           1.8522|
# |England: Premier ...|         Bolton|     West Brom|           1.6122|
# |England: Premier ...|Manchester City|   Southampton|              1.7|
# |England: Premier ...|  Newcastle Utd|    Birmingham|           1.8622|
# |England: Premier ...|     Portsmouth|       Norwich|           1.6344|
# |England: Champion...|          Derby|       Cardiff|           1.6875|
# |England: Champion...|        Ipswich|      West Ham|           1.8363|
# |England: Champion...|          Leeds|         Crewe|           1.8675|
# |England: Champion...|            QPR|      Brighton|           1.8388|
# |England: Champion...|         Wolves|      Plymouth|           1.8713|
# | England: League One|    Bournemouth|     Brentford|             1.85|
# | England: League One|   Bristol City|  Peterborough|           1.5378|
# | England: League One|      Hull City|  Huddersfield|           1.5911|
# | England: League One|          Luton| Sheffield Wed|             1.86|
# | England: League One|        Swindon|    Colchester|             1.78|
# | England: League One|        Torquay|     Stockport|           1.7344|
# | England: League One|        Walsall|     Doncaster|           1.9022|
# | England: League One|        Wrexham|     Blackpool|           1.8922|
# | England: League Two|    Northampton|     Mansfield|              1.7|
# +--------------------+---------------+--------------+-----------------+
# only showing top 20 rows
#
# +--------------------+--------------------+----------+----------+--------------------+
# |              league|           home_team|home_score|away_score|           away_team|
# +--------------------+--------------------+----------+----------+--------------------+
# |England: Premier ...|   Manchester United|         0|         0|           Tottenham|
# |     England: FA Cup|   Manchester United|         0|         0|              Exeter|
# |England: Premier ...|   Manchester United|         3|         1|         Aston Villa|
# |England: Carling Cup|   Manchester United|         1|         2|             Chelsea|
# |     England: FA Cup|   Manchester United|         3|         0|       Middlesbrough|
# |England: Premier ...|   Manchester United|         2|         0|          Birmingham|
# |World: Friendly I...|United Arab Emirates|         1|         2|         Switzerland|
# |Europe: Champions...|   Manchester United|         0|         1|            AC Milan|
# |England: Premier ...|   Manchester United|         2|         1|          Portsmouth|
# |England: Premier ...|   Manchester United|         1|         0|              Fulham|
# |England: Premier ...|   Manchester United|         0|         0|           Blackburn|
# |            USA: MLS|           DC United|         1|         1|        Chicago Fire|
# |            USA: MLS|           DC United|         3|         4|New England Revoluti|
# |England: Premier ...|   Manchester United|         2|         1|       Newcastle Utd|
# |  Sweden: Superettan|          AFC United|         0|         1|              Osters|
# |England: Premier ...|   Manchester United|         1|         1|           West Brom|
# |            USA: MLS|           DC United|         3|         1|       Columbus Crew|
# |  Sweden: Superettan|          AFC United|         1|         0|         Trelleborgs|
# |England: Premier ...|   Manchester United|         1|         3|             Chelsea|
# |            USA: MLS|           DC United|         3|         2|Sporting Kansas City|
# +--------------------+--------------------+----------+----------+--------------------+
# only showing top 20 rows

# %% [markdown]
# ## Group By and Aggregate
#
# Performe a group by and aggregat operation

# %%
from pyspark.sql.functions import count, avg, sum, min, max, desc

df.groupBy("league") \
  .agg(count("*").alias("n_spiele")) \
  .show()

df.groupBy("home_team") \
  .agg(
    sum("home_score").alias("total_home_goals"),
    max("home_score").alias("max_home_goals_in_match")
  ) \
  .orderBy(desc("total_home_goals")) \
  .show(10)
# Out:
# +--------------------+--------+
# |              league|n_spiele|
# +--------------------+--------+
# |Africa: Africa Cu...|     467|
# |USA: Atlanta MLS ...|       2|
# | Mexico: Copa Mexico|     471|
# |Azerbaijan: Super...|       1|
# |Belgium: Proximus...|     306|
# | Morocco: Botola Pro|     185|
# |Netherlands: KNVB...|     520|
# |Germany: Regional...|    2010|
# |    Ecuador: Serie A|    2218|
# |Bulgaria: Bulgari...|     244|
# |South Africa: Fir...|     409|
# |Germany: Oberliga...|      36|
# |Australia: Capita...|      74|
# |Slovakia: Fortuna...|     198|
# |Germany: Oberliga...|      18|
# |Germany: Oberliga...|      32|
# |Sweden: Super Cup...|       3|
# |FYR of Macedonia:...|       1|
# | Austria: Erste Liga|    1312|
# |   Asia: Asian Games|     105|
# +--------------------+--------+
# only showing top 20 rows
# [Stage 67:>                                                         (0 + 1) / 1]
# +-----------+----------------+-----------------------+
# |  home_team|total_home_goals|max_home_goals_in_match|
# +-----------+----------------+-----------------------+
# |  Barcelona|             849|                      9|
# |    Rangers|             811|                      8|
# |Real Madrid|             794|                      9|
# |River Plate|             749|                      7|
# |      Basel|             691|                      7|
# |    Everton|             691|                      7|
# |   Salzburg|             677|                      8|
# |U. Catolica|             665|                      8|
# |    Chelsea|             662|                      8|
# |    Benfica|             648|                      8|
# +-----------+----------------+-----------------------+
# only showing top 10 rows

# %% [markdown]
# ## Save DataFrame to Parquet

# %%
df.write \
  .mode("overwrite") \
  .parquet("./closing_odds_parquet")

# %%
spark.stop()
